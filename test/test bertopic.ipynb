# %% [markdown]
# ## Test Bertopic

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import json
from datetime import datetime
from dateutil.parser import parse
from dotenv import load_dotenv

#from ITBA-NLP.NLP_tools import Cleaning_text, top_keywords, top_entities, get_topic_name, best_document, init_opensearch, clean_all

import spacy

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import unicodedata
from tqdm import tqdm

from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer

#from opensearch_data_model import Topic, TopicKeyword, News, os_client, TOPIC_INDEX_NAME, NEWS_INDEX_NAME

# %%
from datasets import load_dataset_builder
from datasets import load_dataset
from datasets import get_dataset_split_names

# %%
dataset = load_dataset("jganzabalseenka/news_2024-06-02_24hs")

# %%
get_dataset_split_names("jganzabalseenka/news_2024-06-02_24hs")
# Out:
# ['train']

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['asset_id', 'title_ch', 'media', 'impact', 'start_time_utc', 'start_time_local', 'entities_curated', 'entities', 'predicted_at_entities', 'entities_raw_transformers', 'entities_transformers', 'title', 'text', 'keywords', 'predicted_at_keywords', 'truncated_text', 'title_and_text', 'prediction_delay_predictions', 'prediction_delay'],
#         num_rows: 15094
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['asset_id', 'title_ch', 'media', 'impact', 'start_time_utc', 'start_time_local', 'entities_curated', 'entities', 'predicted_at_entities', 'entities_raw_transformers', 'entities_transformers', 'title', 'text', 'keywords', 'predicted_at_keywords', 'truncated_text', 'title_and_text', 'prediction_delay_predictions', 'prediction_delay'],
#     num_rows: 15094
# })

# %%
df = pd.DataFrame(dataset['train'])
df.head(1)
# Out:
#     asset_id                                           title_ch    media  \
# 0  110445113  Sorpresa en Atlético Nacional: se quedaría con...  Infobae
#
#    impact      start_time_utc    start_time_local entities_curated  \
# 0  566715 2024-06-02 03:18:00 2024-06-02 00:18:00               []
#
#                                             entities  \
# 0  [Edwin Cardona, Juan Felipe, Juan David Londoñ...
#
#        predicted_at_entities  \
# 0 2024-06-02 03:33:45.737059
#
#                            entities_raw_transformers  \
# 0  [{'entities': [{'end': 29, 'entity_group': 'OR...
#
#                                entities_transformers  \
# 0  [Atlético Nacional, Diego Ariza, Pablo Reppeto...
#
#                                                title  \
# 0  Sorpresa en Atlético Nacional: se quedaría con...
#
#                                                 text  \
# 0  2 Jun, 2024 Por  Diego Ariza Nuevo Atlético Na...
#
#                                             keywords  \
# 0  [institución, periodista árabe, club, libertad...
#
#        predicted_at_keywords  \
# 0 2024-06-02 03:46:56.781300
#
#                                       truncated_text  \
# 0  2 Jun, 2024 Por  Diego Ariza Nuevo Atlético Na...
#
#                                       title_and_text  \
# 0  Sorpresa en Atlético Nacional: se quedaría con...
#
#    prediction_delay_predictions  prediction_delay
# 0                      0.219735          0.482439

# %%
len(df)
# Out:
# 15094

# %%
load_dotenv()
PATH_REMOTO='/content/ITBA-NLP/data/'
PATH=os.environ.get('PATH_LOCAL', PATH_REMOTO)

# %%
df_params = {'0_1000':'0_1000_data.parquet' }

chunk = '0_1000'

df_parquet = pd.read_parquet(PATH+df_params[chunk])

df =  df_parquet[:1000]
data_title = list(df['in__title'])
data = list(df['in__text'])
# Cantidad total de documentos
len(data)
# Out:
# 1000

# %%
data_title[:10]

# %% [markdown]
# ## Test 1

# %%
tf_vectorizer = CountVectorizer(
    encoding='utf-8',
    # strip_accents='ascii',
    # lowercase=True, #(default)
    # tokenizer=None,
    # stop_words=SPANISH_STOPWORDS,
    ngram_range=(1, 2),
    # max_df=0.8,
    # min_df=0.1,
    # max_features=None,   
    # vocabulary=None,
)
tf_vectorizer.fit(data)

topic_model = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=
Index([191, 246, 279, 303, 312, 345, 372, 434, 506, 521, 529, 649, 692, 713,
#         727, 728, 761, 769, 770, 809, 822, 854, 876, 896, 931, 980],
#        dtype='int64'),
#  10: Index([  8,  52,  67,  72, 123, 151, 182, 201, 226, 288, 292, 340, 464, 532,
#         603, 654, 885, 918, 928, 933, 957, 978],
#        dtype='int64'),
#  11: Index([ 31,  54, 110, 247, 267, 296, 297, 301, 363, 401, 443, 462, 709, 721,
#         738, 768, 835, 881, 939, 965],
#        dtype='int64'),
#  12: Index([  0,  12,  97, 121, 142, 283, 295, 418, 487, 492, 525, 546, 589, 598,
#         863, 867, 901, 950, 995, 996],
#        dtype='int64'),
#  13: Index([102, 175, 209, 294, 305, 341, 344, 373, 391, 467, 516, 602, 655, 667,
#         772, 811, 865, 868, 893],
#        dtype='int64'),
#  14: Index([ 56,  65,  80, 108, 124, 130, 207, 256, 300, 376, 407, 410, 425, 571,
#         647, 665, 804, 961],
#        dtype='int64'),
#  15: Index([15, 30, 40, 43, 120, 218, 310, 335, 554, 599, 625, 644, 886, 924], dtype='int64'),
#  16: Index([136, 162, 223, 254, 354, 359, 420, 505, 517, 907, 966, 991], dtype='int64'),
#  17: Index([69, 74, 128, 169, 272, 349, 489, 584, 710, 801, 982], dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics[topico]:
    print(doc," ",data_title[doc], probs[doc])
len(docs_per_topics[topico])
# Out:
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 0.9797422302944493
# 82   Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.6713453596041968
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# 95   La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 1.0
# 99   Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.6861234458332404
# 101   ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.48130452289007114
# 105   La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 0.8682081335428566
# 106   El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 0.9910596264160193
# 119   Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 1.0
# 137   River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# 150   Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# 158   Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.7628169615202544
# 170   El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.8174018567848234
# 174   La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# 176   Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# 178   En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 0.9975976167739716
# 186   River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 1.0
# 187   De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# 189   Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 194   Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 0.7582976346909505
# 204   CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# 208   Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# 214   Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# 220   Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# 221   Sinner extiende un año colosal en Miami 0.8212599316932779
# 222   Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# 230   Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 1.0
# 239   Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# 244   "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# 257   Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# 261   Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.6763146402566207
# 265   Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# 269   Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.5512158066982302
# 270   Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 0.9958493018931786
# 271   Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.4217641369883254
# 275   El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# 277   Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# 278   Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 1.0
# 281   Tras una odisea, River llegó a Venezuela 1.0
# 282   Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 285   Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# 287   Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.996002773261745
# 307   Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.8989051738107848
# 319   LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.44414081880856454
# 324   Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.8131696752051139
# 325   Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# 348   Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.5097246807917877
# 356   Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# 358   Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.6628899072630842
# 361   Internaron a Cesar Luis Menotti y crece la preocupación 0.6278067995969924
# 362   Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# 364   Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# 369   Emilia María Alvarado Morales 1.0
# 377   Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# 378   El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# 379   Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.7456299127254858
# 387   Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.4989930729226444
# 392   Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# 405   Cagliari empata el juego ante Hellas Verona 1.0
# 408   La razón por la que Alemania sacó de circulación camiseta con el número 44 0.47281049064093245
# 409   La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# 415   "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# 423   Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.8881082259432888
# 426   Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# 431   Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# 448   Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.7304397642948135
# 449   Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# 454   El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# 457   Racing tuvo un día libre mientras disfruta de un presente bárbaro 1.0
# 460   Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 0.9642542570723402
# 474   Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# 475   Udinese visita a Sassuolo por la fecha 30 0.8649369582150012
# 486   Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# 491   Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.6347293534035594
# 495   Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 0.8915682184731568
# 503   ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# 507   El jujeño Calderari recibió el "ok" de Zielinski en Lanús 1.0
# 510   Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# 511   Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 0.9207501555328446
# 513   Godoy Cruz visita a Platense para quedar como único líder 0.724162951351448
# 526   Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# 527   Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# 530   Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# 533   Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# 539   El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# 547   Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# 552   Milett Figueroa le mandó un mensaje a Marcelo Tinelli por su cumpleaños: "Pronto juntos, te amo siempre" 0.4033619166629584
# 559   Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 1.0
# 568   River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# 569   Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.45912547030652795
# 570   Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 576   Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# 577   Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# 578   Mungo, goleadora pero con las manos vacías con Ardoi 0.8093792270944342
# 581   Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# 585   La historia de Central en sus debuts en la Copa Libertadores 1.0
# 591   Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# 601   Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 614   La Selección alemana cambia su camiseta por una similitud con el logo de la SS | ¿Qué pasó con el nuevo diseño de Adidas? 0.47179160582657714
# 627   Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# 630   La rosarina Nadia Podoroska ganó su segundo título WTA en México 1.0
# 636   (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# 637   ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.8112544056544598
# 639   Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 1.0
# 656   Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# 664   De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 0.6676881913068999
# 675   Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.8413083509064933
# 683   ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 689   Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.691722047478599
# 690   Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# 691   Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# 695   Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# 696   El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# 706   Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# 718   Un ex funcionario de Ucrania predijo que Zelenski será "un don nadie" 0.6770148952838864
# 719   La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# 722   Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.8059920189167673
# 725   La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# 726   Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# 733   Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# 739   Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# 742   Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.6737152435972784
# 748   Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 1.0
# 749   Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# 750   Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# 754   ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 756   Walter Perazzo: "Hicimos méritos para el empate" 1.0
# 762   Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# 765   Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# 784   La lista de Belgrano para su debut internacional, con un par de regresos importantes 0.9413130017046947
# 792   Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# 808   El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# 813   Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# 816   Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# 831   Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.6773381721234646
# 836   Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.8158467353019497
# 838   Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 1.0
# 841   Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# 845   Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# 849   Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# 852   Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 1.0
# 855   Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 1.0
# 857   Los 10 datos más curiosos en la historia de la NBA 0.45684777004475774
# 874   La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# 878   Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 1.0
# 894   La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# 903   Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# 904   Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# 906   Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 0.9573942096541765
# 908   Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.7960443549284485
# 914   Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 923   Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# 925   Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# 930   Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# 947   La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 0.9778028927426448
# 952   Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 1.0
# 958   ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# 963   Gabigol en otra polémica: su continuidad en Flamengo 0.8034916470633456
# 970   El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 1.0
# 975   Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# 976   Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# 979   Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# 981   Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# 988   El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# 990   La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 166

# %%
topico = 8
for doc in docs_per_topics[topico]:
    print(doc," ",data_title[doc], probs[doc])
len(docs_per_topics[topico])
# Out:
# 55   Caos y demoras tras el fin de semana XXL: filas kilométricas en el regreso a la Ciudad de Buenos Aires 1.0
# 68   Llegó el último día para una leyenda de Las Vegas: cierra el histórico casino Tropicana 0.42921704889911017
# 112   Durante el fin de semana XXL viajaron más de 3,2 millones de turistas: cuánto gastaron en su descanso 0.5596687660132279
# 139   El gobierno uruguayo celebró el regreso del turismo argentino durante la Semana Santa 0.9313543510270966
# 177   Con el 90% de ocupación hotelera, Termas de Río Hondo fue uno de los destinos más elegidos en Semana Santa 1.0
# 227   Mejores números que en el verano: cuáles fueron los destinos de Río Negro que fueron furor en Semana Santa 0.9534364974378543
# 266   Día de la Donación de Médula Ósea: lanzan una colecta de sangre 0.5714811750307589
# 290   El pueblo colonial lleno de paz que es ideal para visitar un día y escapar de la ciudad - MDZ Online 0.8975287682406622
# 331   Leo Nardini inauguró los pavimentos de las calles Honduras, Cuba y Colombia 0.8612662820104713
# 332   Advierten demoras en la frontera con Chile por el regreso de turistas a Mendoza 1.0
# 368   Cómo funcionan los colectivos en Bahía Blanca durante este lunes feriado 0.8244881563072299
# 406   Un fin de semana largo récord en la costa: qué factores aceleraron la vuelta a casa que ya genera demoras en las rutas 0.6323923051947403
# 417   Lo que hay que saber sobre el eclipse solar total de la semana próxima en México, EEUU y Canadá 0.3816403058987599
# 579   Neuquén despide el verano en las aguas del Limay: guardavidas terminaron su trabajo 0.6941903244678513
# 590   Se redujo la llegada de turistas a Rosario durante Semana Santa | Más consecuencias de la violencia narco 1.0
# 640   Marcos Torres: "Hay que revalorizar lo importante de estos encuentros" en Alta Gracia | Perfil 1.0
# 645   Detuvieron a una mujer, le quitó el arma al guardia y empezó a los tiros 0.6303760345419853
# 657   La ONU busca al "mejor pueblo del mundo" y Santa Fe postula a doce localidades 1.0
# 735   Operadores turísticos hicieron un balance "muy bueno" del feriado largo de Semana Santa en Mar del Plata 0.9302082607386105
# 794   Semana Santa continúa a pleno en Las Grutas 0.5812273158634335
# 812   Semana Santa: Gobierno celebra récord de turistas en el país 1.0
# 815   Del súper lunes teatral con Moldavsky, Laurita Fernández e Imanol Arias a la humorada de Carlos Rottemberg 1.0
# 832   Concepción: el boom gastronómico y cultural de Chile, a solo dos horas de Buenos Aires 0.7230612944620487
# 864   Dónde ubicar el romero para activar sus propiedades y tener trabajo durante todo el año 0.4871163175007996
# 890   Venden un emblemático castillo de más de 100 años ubicado en una isla privada 0.6730905618983418
# 944   Colapso en el regreso de la Costa antes del cierre del fin de semana XXL 1.0
# 994   Semana Santa en Córdoba: calificaron como "excelente" el movimiento turístico 1.0
# 27

# %%
len(docs_per_topics[-1])
# Out:
# 221

# %%
# Obtenemos embeddings de todos los documentos
docs_embedding = topic_model.embedding_model.embed(data)

# %%
len(docs_embedding)
# Out:
# 100

# %%
len(docs_embedding[0])
# Out:
# 384

# %% [markdown]
# - CONCLUSION:
#     - Con 100 registros:
#     - sin preprocesamiento de data
#     - sin vocabulario
#     - sin ajustes de bertopic
#     - solo CountVectorizer
#         - Resultado Clasifica en dos Topicos, el resto al -1.

# %% [markdown]
# ## Test 2 - con TFIDF

# %%
tfidf_vectorizer_2 = TfidfVectorizer(
    # tokenizer=tokenizer,
    # max_df=0.8,
    # min_df=0.2,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    #lowercase=False,
    #vocabulary=all_tokens,
    # max_features=100_000
)
tfidf_vectorizer_2.fit(data)

topic_model_2 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_2
)

topics_2, probs_2 = topic_model_2.fit_transform(data)

# %%
T_2 = topic_model_2.get_document_info(data)
docs_per_topics_2 = T_2.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_2
# Out:
# {-1: Index([  3,   4,  22,  28,  32,  43,  44,  47,  48,  51,
#         ...
#         929, 937, 940, 945, 946, 955, 962, 964, 974, 998],
#        dtype='int64', length=181),
#  0: Index([ 23,  39,  82,  93,  95,  99, 101, 105, 106, 119,
#         ...
#         952, 958, 963, 970, 975, 976, 979, 981, 988, 990],
#        dtype='int64', length
unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.9557210536442518
# LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.5605773361404454
# Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.7316012485905175
# Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.45681877052981956
# Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.6823327155785247
# Internaron a Cesar Luis Menotti y crece la preocupación 0.7363265051682463
# Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# Emilia María Alvarado Morales 0.9049474741103029
# Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 0.9748126023333976
# Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.8202203532268943
# Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.5220669754019991
# Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# Cagliari empata el juego ante Hellas Verona 1.0
# La razón por la que Alemania sacó de circulación camiseta con el número 44 0.4973906534833304
# La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.7392109234510381
# Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.7528026654285573
# Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 0.9784618397654634
# Racing tuvo un día libre mientras disfruta de un presente bárbaro 1.0
# Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 1.0
# Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# Udinese visita a Sassuolo por la fecha 30 1.0
# Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.7141860124695107
# Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# El jujeño Calderari recibió el "ok" de Zielinski en Lanús 1.0
# Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 1.0
# Godoy Cruz visita a Platense para quedar como único líder 0.7227688742823218
# Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 1.0
# River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.4981911522295377
# Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# Mungo, goleadora pero con las manos vacías con Ardoi 0.915358136868502
# Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# La historia de Central en sus debuts en la Copa Libertadores 1.0
# Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# La Selección alemana cambia su camiseta por una similitud con el logo de la SS | ¿Qué pasó con el nuevo diseño de Adidas? 0.49314285998589036
# Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# La rosarina Nadia Podoroska ganó su segundo título WTA en México 0.8904407596468001
# (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.8001981958554502
# Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 0.9890645118278
# Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 1.0
# Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 1.0
# ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.7290366870447974
# Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.7767829516116576
# La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.6901803457042781
# Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.9256558234664768
# Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Walter Perazzo: "Hicimos méritos para el empate" 1.0
# Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# La lista de Belgrano para su debut internacional, con un par de regresos importantes 1.0
# Atacó a golpes a su padre porque le pidió plata y no tenía 0.5006120936692374
# Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# Por qué Marcelo Tinelli pasó su cumpleaños a 10 mil kolómetros de Milett Figueroa según Yanina Latorre 0.36240031170146086
# Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.8379202425109582
# Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.8814721142542994
# Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 0.9205117970228138
# Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 1.0
# Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 1.0
# Los 10 datos más curiosos en la historia de la NBA 0.5774314773692194
# La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 0.9573868294131247
# La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.8215319051876019
# Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 0.823396827987227
# Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 0.8744597779008035
# ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# Gabigol en otra polémica: su continuidad en Flamengo 1.0
# El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 0.9008057284987144
# Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 166

# %%
topico = 1
for doc in docs_per_topics_2[topico]:
    print(data_title[doc], probs_2[doc])
len(docs_per_topics_2[topico])
# Out:
# Elecciones en Venezuela: María Corina Machado pidió más apoyo de Noruega para garantizar unas presidenciales libres 1.0
# En abril crecerá la protesta sindical: se prevé una oleada de paros que incluirá al transporte, estatales, docentes y la CGT 0.7364586229850156
# Trias no descarta un pacto Junts-PSC tras el 12-M: "El problema es para hacer qué" 0.9237910520248518
# El PP acusa a Sánchez y Begoña Gómez de "tráfico de influencias conyugal" y Bolaños dice que sus palabras son miserables 0.9168429875859485
# El Gobierno investiga más irregularidades: el software de casi un millón de dólares y los vehículos de alta gama 0.7818554361019956
# Estados Unidos y el rol de la APEP 0.7086859123836917
# Se profundiza la crisis inmobiliaria de China: Country Garden suspendió la cotización en la bolsa de Hong Kong 0.964301605663641
# NC-BC critica la "inacción" del Gobierno con las maniobras militares de Marruecos 1.0
# La CTA Autónoma alertó que habrá nuevas medidas por los despidos en el Estado tras las protestas de mañana 1.0
# La jefa del Comando Sur de Estados Unidos llega a Argentina para advertir sobre China - MDZ Online 1.0
# Rusia acusa al jefe del Comité Olímpico Internacional de "conspiración" para excluir a sus atletas 0.909297182541239
# La Izquierda en contra de la visita de una jefa del Ejército de Estados Unidos 0.8166106802725412
# Guillermo Francos salió al cruce de los gobernadores que criticaron el ajuste | Más encontronazos del gobierno con las provincias 1.0
# Donald Trump, entre encuestas y juicios penales - El Economista 1.0
# El Gobierno y Colombia dan por superadas las diferencias 1.0
# A Maduro hay que derrotarlo ahora 1.0
# Malvinas: los gobernadores patagónicos encabezaron la vigilia y enviaron una señal de unidad a la Casa Rosada 1.0
# Catalina habría recibido información de Gran Hermano 1.0
# ¿Por qué no te vas a vivir a Cuba? 1.0
# Así quedó el hospital de Al-Shifa, el más grande de Gaza, tras la retirada de Israel 1.0
# Francos le respondió a Pullaro tras su cuestionamiento por el ajuste a los pobres: "Lo están sufriendo como todos los argentinos" 1.0
# La victoria aplastante de la oposición siembra de dudas el futuro de Recep Tayyip Erdogan 1.0
# Elisa Carrió comparó a Javier Milei con Menem, Kirchner y Zelensky: "Es muy buen actor" 1.0
# La retórica migratoria de Trump se gana a algunos demócratas, una posible preocupación para Biden 0.9441026983925289
# La canciller de AMLO quiere imitar a Petro y echar a los diplomáticos de Milei, pero el presidente la frena 1.0
# Paritaria siderúrgica: la UOM marcha este jueves a San Nicolás 0.8862020014102978
# Después de varias postergaciones, le pusieron fecha a la indagatoria de Ginés González García por el vacunatorio VIP 0.8890902582806455
# Reapareció Carrió, estalló contra Milei y Karina y avisó: "No somos colaboracionistas de este gobierno" 1.0
# La desmalvinizacion vista desde Malvinas 0.7997107762026167
# Weretilneck no viaja a la vigilia de Malvinas y se prepara para retomar negociaciones salariales 1.0
# Conflicto con Colombia: El regreso del embajador 1.0
# 132

# %%
len(docs_per_topics_2[-1])
# Out:
# 181

# %% [markdown]
# - 2. Con 100 registros:
#     - sin preprocesamiento
#     - sin vocabulario
#     - sin ajustes de bertopic
#     - con TFIDFVectoizer
#         - Resultado: Clasifica en dos topicos tambien, pero restringe un poco la cantidad de docs:
#             - del topico 0, de 71 (Test 1) a 61.
#             - del topico 1, de 21 (Test 1) a 19.
#             - Esto podria explicar que selecciona mejor los docs del topico 0, que es usualmente el de mayor cantidad de docs.

# %% [markdown]
# ## Test 3 - con TFIDF y control de parametros y stopwords

# %%
# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS] 

tfidf_vectorizer_3 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.8,
    min_df=2,
    ngram_range=(1, 2),
    stop_words=SPANISH_STOPWORDS,
    #lowercase=False,
    #vocabulary=all_tokens,
    # max_features=100_000
)
tfidf_vectorizer_3.fit(data)

topic_model_3 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_3
)

topics_3, probs_3 = topic_model_3.fit_transform(data)

# %%
len(tfidf_vectorizer_3.get_feature_names_out())
# Out:
# 23995

# %%
T_3 = topic_model_3.get_document_info(data)
docs_per_topics_3 = T_3.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics
vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.6860807699699709
# ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.5745292420833042
# La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 0.9304180273178658
# El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 1.0
# Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 1.0
# River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.7642168611947174
# El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.9096088921638543
# La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 1.0
# River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 1.0
# De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 1.0
# CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# Sinner extiende un año colosal en Miami 0.8354470557378681
# Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 1.0
# Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.882798818709651
# Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.6634096241125416
# Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 1.0
# Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.5512623541311865
# El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 0.973266547544346
# Tras una odisea, River llegó a Venezuela 1.0
# Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.988196760626023
# Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.8984747883707797
# LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.5903654435063244
# Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.8150126065094212
# Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.4607872055818473
# Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.8878309207508135
# Internaron a Cesar Luis Menotti y crece la preocupación 0.7436823691650548
# Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# Emilia María Alvarado Morales 1.0
# Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.9728846323473342
# Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.5091789238935359
# Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# Cagliari empata el juego ante Hellas Verona 1.0
# La razón por la que Alemania sacó de circulación camiseta con el número 44 0.4988273673122247
# La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.8571079844019079
# Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.8323429769844941
# Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# Racing tuvo un día libre mientras disfruta de un presente bárbaro 1.0
# Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 1.0
# Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# Udinese visita a Sassuolo por la fecha 30 0.9140165868514653
# Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.8901715198939195
# Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# El jujeño Calderari recibió el "ok" de Zielinski en Lanús 0.9285947822386493
# Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 1.0
# Godoy Cruz visita a Platense para quedar como único líder 0.7377227399377501
# Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 1.0
# River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.49282799790639076
# Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# Mungo, goleadora pero con las manos vacías con Ardoi 0.9728846323473342
# Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# La historia de Central en sus debuts en la Copa Libertadores 1.0
# Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# La Selección alemana cambia su camiseta por una similitud con el logo de la SS | ¿Qué pasó con el nuevo diseño de Adidas? 0.5030460257269763
# Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# La rosarina Nadia Podoroska ganó su segundo título WTA en México 0.8901715198939195
# (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.9052320055397205
# Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 1.0
# Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 1.0
# Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.8773561424924545
# ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.7936820080383356
# Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.9253761461228511
# La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.8117364424499754
# Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.8715788163558845
# Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Walter Perazzo: "Hicimos méritos para el empate" 1.0
# Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# La lista de Belgrano para su debut internacional, con un par de regresos importantes 1.0
# Atacó a golpes a su padre porque le pidió plata y no tenía 0.5326910407391573
# Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# Por qué Marcelo Tinelli pasó su cumpleaños a 10 mil kolómetros de Milett Figueroa según Yanina Latorre 0.37535182085801483
# Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.8854995124874637
# Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.9639045761945193
# Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 0.9955289620121607
# Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 1.0
# Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 0.9755287240251036
# Los 10 datos más curiosos en la historia de la NBA 0.5859857029393398
# La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 1.0
# La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.8299784918315773
# Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 1.0
# Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 0.9772860032187357
# ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# Gabigol en otra polémica: su continuidad en Flamengo 0.9377976272021588
# El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 1.0
# Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 166

# %%
topico = 1
for doc in docs_per_topics_3[topico]:
    print(data_title[doc], probs_3[doc])
len(docs_per_topics_3[topico])
# Out:
# Elecciones en Venezuela: María Corina Machado pidió más apoyo de Noruega para garantizar unas presidenciales libres 1.0
# Trias no descarta un pacto Junts-PSC tras el 12-M: "El problema es para hacer qué" 1.0
# El PP acusa a Sánchez y Begoña Gómez de "tráfico de influencias conyugal" y Bolaños dice que sus palabras son miserables 0.9408213071943045
# El Gobierno investiga más irregularidades: el software de casi un millón de dólares y los vehículos de alta gama 0.8517837742994738
# Estados Unidos y el rol de la APEP 0.8699360437332312
# Se profundiza la crisis inmobiliaria de China: Country Garden suspendió la cotización en la bolsa de Hong Kong 0.9925774166493564
# Milei cargó otra vez contra los gobernadores – frente a Cano 1.0
# Críticas y quejas por la paralización de la obra del Viaducto de Burzaco 1.0
# Malvinas: en busca de una tercera vía 0.7333576256938182
# "El peronismo está en la boludez de discutir liderazgos y la gente se hinchó las pelotas de nosotros" 1.0
# La jefa del Comando Sur de Estados Unidos llega a Argentina para advertir sobre China - MDZ Online 0.9375597561939014
# Rusia acusa al jefe del Comité Olímpico Internacional de "conspiración" para excluir a sus atletas 0.8012177409209953
# La Izquierda en contra de la visita de una jefa del Ejército de Estados Unidos 0.9136560518713331
# Guillermo Francos salió al cruce de los gobernadores que criticaron el ajuste | Más encontronazos del gobierno con las provincias 1.0
# Donald Trump, entre encuestas y juicios penales - El Economista 1.0
# El Gobierno y Colombia dan por superadas las diferencias 1.0
# A Maduro hay que derrotarlo ahora 1.0
# Malvinas: los gobernadores patagónicos encabezaron la vigilia y enviaron una señal de unidad a la Casa Rosada 1.0
# Catalina habría recibido información de Gran Hermano 1.0
# ¿Por qué no te vas a vivir a Cuba? 1.0
# Así quedó el hospital de Al-Shifa, el más grande de Gaza, tras la retirada de Israel 0.8460569951009722
# Francos le respondió a Pullaro tras su cuestionamiento por el ajuste a los pobres: "Lo están sufriendo como todos los argentinos" 1.0
# Reabrió la estación Facultad de Medicina de la Línea D de subtes 0.7452279970946664
# La victoria aplastante de la oposición siembra de dudas el futuro de Recep Tayyip Erdogan 1.0
# Elisa Carrió comparó a Javier Milei con Menem, Kirchner y Zelensky: "Es muy buen actor" 1.0
# La retórica migratoria de Trump se gana a algunos demócratas, una posible preocupación para Biden 0.9527762908137861
# La canciller de AMLO quiere imitar a Petro y echar a los diplomáticos de Milei, pero el presidente la frena 1.0
# Paritaria siderúrgica: la UOM marcha este jueves a San Nicolás 0.9981232014033531
# Después de varias postergaciones, le pusieron fecha a la indagatoria de Ginés González García por el vacunatorio VIP 1.0
# Reapareció Carrió, estalló contra Milei y Karina y avisó: "No somos colaboracionistas de este gobierno" 1.0
# La desmalvinizacion vista desde Malvinas 0.9802659068209024
# Weretilneck no viaja a la vigilia de Malvinas y se prepara para retomar negociaciones salariales 1.0
# Conflicto con Colombia: El regreso del embajador 1.0
# 134

# %%
len(docs_per_topics_3[-1])
# Out:
# 189

# %% [markdown]
# - 3. Con 100 registros:
#     - sin preprocesamiento
#     - sin vocabulario
#     - sin ajustes de bertopic
#     - con TFIDFVectoizer + parametrizacion min_df max_df y stop words
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 2
#             - del topico 0, de 61 (Test 2) a 65.
#             - del topico 1, de 19 (Test 2) a 18.

# %% [markdown]
# ## Test 4 - Entrenamos agregando un vocabulario con stopwords
# - Esto implica que el TfidfVectorizer solo considerará las palabras y n-gramas que están en ese vocabulario, no realizará ninguna acción sobre las palabras de los documentos.

# %%
# Cargar el modelo de spaCy para español
spa = spacy.load("es_core_news_lg")

# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS] 

# Detectar entidades para todos los documentos usando spaCy
entities_spa = []
for doc in tqdm(data):
    extract = spa(doc)
    entities_spa.append([(ent.text, ent.label_) for ent in extract.ents])

# Procesamiento de entidades encontradas
entities = []
original_entities = []
word_count = {}
for item in tqdm(entities_spa):
    for ent in item:
        if ent[1] == 'PER' or ent[1] == 'ORG' or ent[1] == 'LOC':
            token = str(ent[0]).lower()  
            if token not in word_count:
                word_count[token] = {'count': 0, 'original': ent[0]}
                
            word_count[token]['count'] += 1   
    
    # Ordenar el diccionario por el valor del conteo en orden descendente
    sorted_word_count = dict(sorted(word_count.items(), key=lambda item: item[1]['count'], reverse=True))  

    word_count = {}

    # Crear la lista de entidades procesadas por noticia (para guardar en DB)
    original_entities.append( [value['original'] for _, value in sorted_word_count.items() 
                                if value['original'].lower() not in SPANISH_STOPWORDS_SIN_ACENTOS and len(value['original'].split()) < 5] )

    # Crear la lista de entidades procesadas por noticia (entrenamiento)
    pre_entities = clean_all( [key for key, _ in sorted_word_count.items()
                                if key not in SPANISH_STOPWORDS_SIN_ACENTOS and len(key.split()) < 5 ] )

    # entidades para entrenar
    entities.append( pre_entities )
# Out:
# 100%|██████████| 1000/1000 [02:33<00:00,  6.50it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1174.97it/s]

# %%
# Vocabulario
preprocessed_entities = []
registro = ""
for array in entities:
    
    for ent in array:
        if len(ent.split()) > 2:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:    
                    preprocessed_entities.append(word)
                elif word.isnumeric() and len(word) == 4:
                    preprocessed_entities.append(word)
        else:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:  
                    registro += word + " "
            if registro:
                preprocessed_entities.append(registro.strip())
                registro = ""

vocab_entities = list(set([item for item in preprocessed_entities]))
len(vocab_entities)
# Out:
# 9272

# %%
tfidf_vectorizer_4 = TfidfVectorizer(
    # tokenizer=tokenizer,
    # max_df=0.8,
    # min_df=0.2,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    vocabulary=vocab_entities,
    # max_features=100_000
)
tfidf_vectorizer_4.fit(data)

topic_model_4 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_4
)

topics_4, probs_4 = topic_model_4.fit_transform(data)

# %%
T_4 = topic_model_4.get_document_info(data)
docs_per_topics_4 = T_4.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_4
# Out:
# {-1: Index([  3,   4,  10,  12,  21,  22,  24,  25,  26,  43,
#         ...
#         938, 940, 945, 946, 948, 955, 962, 974, 985, 993],
#        dtype='int64', length=191),
#  0: Index([ 23,  39,  82,  93,  95,  99, 101, 105, 106, 119,
#         ...
#         952, 958, 963, 970, 975, 976, 979, 981, 988, 990],
#        dtype='int64', length=167),
#  1: Index([  1,   6,   9,  15,  20,  30,  35,  40,  46,  47,
#         ...
#         889, 902, 909, 910, 912, 932, 964, 969, 997, 998],
#        dtype='int64', length=114),
#  2: Index([ 13,  14,  17,  29,  49,  50,  53,  89,  91, 107,
#         ...
#         934, 941, 943, 949, 953, 960, 967, 973, 986, 999],
#        dtype='int64', length=106),
#  3: Index([  5,  18,  36,  41,  58,  63,  64,  70,  77,  79,  81,  85,  87,  94,
#          98, 115, 116, 118, 122, 125, 141, 143, 144, 147, 153, 156, 196, 215,
#         219, 235, 249, 250, 286, 291, 299, 315, 318, 321, 323, 347, 351, 366,
#         374, 384, 390, 400, 403, 437, 440, 441, 451, 469, 481, 482, 485, 496,
#         538, 553, 555, 560, 565, 567, 573, 605, 608, 617, 626, 669, 672, 712,
#         732, 771, 776, 786, 820, 823, 848, 862, 877, 891, 913, 917, 922, 927,
#         935, 951, 959, 971, 977, 983, 984, 987, 989],
#        dtype='int64'),
#  4: Index([  7,  11,  16,  37,  42,  62,  96, 113, 138, 140, 152, 173, 181, 188,
#         216, 225, 298, 304, 360, 383, 399, 412, 433, 455, 497, 535, 550, 563,
#         609, 631, 643, 694, 744, 746, 753, 766, 785, 791, 856, 871, 888, 895,
#         936, 954, 968],
#        dtype='int64'),
#  5: Index([ 59,  97, 111, 159, 195, 202, 206, 237, 252, 280, 293, 343, 398, 421,
#         428, 442, 456, 473, 493, 520, 531, 548, 600, 642, 658, 673, 674, 720,
#         723, 790, 803, 825, 853, 870, 873, 919, 942, 992],
#        dtype='int64'),
#  6: Index([ 33,  60, 200, 231, 238, 248, 262, 289, 302, 314, 328, 382, 427, 429,
#         430, 445, 480, 501, 561, 583, 620, 623, 624, 651, 687, 716, 751, 752,
#         778, 805, 887, 972],
#        dtype='int64'),
#  7: Index([ 55,  68, 112, 139, 177, 190, 227, 290, 331, 332, 368, 406, 564, 579,
#         590, 640, 645, 657, 735, 794, 812, 815, 832, 864, 890, 944, 994],
#        dtype='int64'),
#  8: Index([191, 246, 279, 303, 312, 345, 372, 434, 506, 521, 529, 649, 692, 713,
#         727, 728, 761, 769, 770, 809, 822, 854, 876, 896, 931, 980],
#        dtype='int64'),
#  9: Index([ 19,  27,  38, 103, 132, 228, 245, 258, 311, 339, 352, 375, 477, 500,
#         536, 676, 701, 814, 860, 861, 898, 956],
#        dtype='int64'),
#  10: Index([  8,  52,  67,  72, 123, 151, 182, 201, 226, 288, 292, 340, 464, 532,
#         603, 654, 885, 918, 928, 933, 957, 978],
#        dtype='int64'),
#  11: Index([ 31,  54, 110, 247, 267, 296, 297, 301, 363, 401, 443, 462, 709, 721,
#         738, 768, 835, 881, 939, 965],
#        dtype='int64'),
#  12: Index([ 34,  56,  65,  80, 108, 124, 130, 207, 256, 300, 376, 407, 410, 425,
#         571, 647, 665, 740, 804, 961],
#        dtype='int64'),
#  13: Index([102, 209, 294, 305, 341, 344, 373, 391, 467, 516, 602, 655, 667, 772,
#         811, 865, 868, 893],
#        dtype='int64'),
#  14: Index([ 28, 136, 162, 223, 253, 254, 354, 359, 417, 420, 505, 517, 574, 759,
#         907, 966, 991],
#        dtype='int64'),
#  15: Index([0, 121, 142, 283, 418, 487, 492, 525, 546, 589, 598, 863, 867, 950, 995,
#         996],
#        dtype='int64'),
#  16: Index([2, 32, 83, 92, 149, 163, 184, 211, 263, 365, 367, 661, 714, 775, 883], dtype='int64'),
#  17: Index([69, 74, 128, 169, 272, 349, 489, 584, 710, 801, 982], dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_4[topico]:
    print(data_title[doc], probs_4[doc])
len(docs_per_topics_4[topico])
# Out:
# Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 1.0
# Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.8002622142845542
# Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 0.9359658730815517
# Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.6595244515554267
# ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.4930727414865186
# La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 0.9270377933619859
# El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 1.0
# Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 1.0
# River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.8185108457722973
# El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.9681277026135118
# La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 0.9443155339976446
# River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 1.0
# De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 0.9887422461742791
# CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# Sinner extiende un año colosal en Miami 0.9444944286270694
# Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 1.0
# Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.927068103493842
# Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.6226307660522473
# Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 0.8040038759541859
# Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.6071257130231412
# El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 1.0
# Tras una odisea, River llegó a Venezuela 1.0
# Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.878771167050095
# Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.9048551836681533
# LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.6170563988060739
# Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.7287941056450962
# Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.4846547468344432
# Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.8021983660756373
# Internaron a Cesar Luis Menotti y crece la preocupación 0.6948517479081917
# Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# Emilia María Alvarado Morales 1.0
# Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.8702714837881368
# Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.5055652565603089
# Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# Cagliari empata el juego ante Hellas Verona 1.0
# La razón por la que Alemania sacó de circulación camiseta con el número 44 0.493581036205953
# La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.9443941000215148
# Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.8566144038052897
# Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# Racing tuvo un día libre mientras disfruta de un presente bárbaro 1.0
# Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 1.0
# Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# Udinese visita a Sassuolo por la fecha 30 0.9393377183274262
# Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.8057884409174059
# Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# El jujeño Calderari recibió el "ok" de Zielinski en Lanús 1.0
# Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 1.0
# Godoy Cruz visita a Platense para quedar como único líder 0.8332059553560518
# Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# Milett Figueroa le mandó un mensaje a Marcelo Tinelli por su cumpleaños: "Pronto juntos, te amo siempre" 0.3861300956143787
# Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 0.9843243471106526
# River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.4933094164807543
# Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# Mungo, goleadora pero con las manos vacías con Ardoi 0.9030837237654629
# Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# La historia de Central en sus debuts en la Copa Libertadores 1.0
# Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# La Selección alemana cambia su camiseta por una similitud con el logo de la SS | ¿Qué pasó con el nuevo diseño de Adidas? 0.49759137213400306
# Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# La rosarina Nadia Podoroska ganó su segundo título WTA en México 1.0
# (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.9258866575886776
# Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 1.0
# Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 1.0
# Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.8702714837881368
# ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.8054311499359674
# Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.9344264263151165
# La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.7990551708572993
# Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.9862778489367439
# Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# Walter Perazzo: "Hicimos méritos para el empate" 1.0
# Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# La lista de Belgrano para su debut internacional, con un par de regresos importantes 1.0
# Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# Por qué Marcelo Tinelli pasó su cumpleaños a 10 mil kolómetros de Milett Figueroa según Yanina Latorre 0.43823238546326154
# Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.904009946067316
# Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 1.0
# Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 1.0
# Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 1.0
# Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 1.0
# Los 10 datos más curiosos en la historia de la NBA 0.691516700942681
# Virus se presenta en el Arena y podés ganar entradas y conocerlos 0.3289277832046482
# La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 1.0
# La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.8526395450041625
# Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 1.0
# Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 0.9857803148265213
# ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# Gabigol en otra polémica: su continuidad en Flamengo 1.0
# El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 1.0
# Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 167

# %%
topico = 1
for doc in docs_per_topics_4[topico]:
    print(data_title[doc], probs_4[doc])
len(docs_per_topics_4[topico])
# Out:
# El populismo derivó en que los argentinos financien el crecimiento de los países desarrollados 0.7483941548342843
# Dólar versus inflación: ¿cuál debería ser el nivel del tipo de cambio? 1.0
# Elogios de un profesor argentino que enseña en Harvard: "Para hacer progresismo hay que hacer lo que está haciendo Milei" 0.8504157102733593
# Bitcoin: cómo se ha movido en el mercado este 2 de abril 0.7194427483318
# Un teclado puede albergar más gérmenes que un inodoro: qué tipo de bacterías 0.5370269800431061
# Criptomonedas: el precio de ethereum para este día 0.6568909052531329
# Se disparó el interés por alquilar departamentos de 4 ambientes en CABA: la oferta subió más de 80 por ciento 0.890093339127818
# Criptomonedas: el valor de tether para este 2 de abril 0.7194427483318
# Exclusivo: con quiénes está negociando el Gobierno para conseguir los USD 15.000 millones que necesita para levantar el cepo 0.5635723857482926
# Café en el horno microondas: Tips para calentarlo de manera segura y sin comprometer el sabor 0.44411325742145635
# En cuatro años, la yerba regulada subió más de 1300%: qué pasará con el mercado liberado 0.5138386899511779
# Licuadora vs motosierra: los detalles de cómo se está llevando adelante el ajuste fiscal del Gobierno de Javier Milei 0.5677587765590822
# Estas son las nuevas regulaciones para vehículos pesados en EEUU que buscan combatir el cambio climático 0.6450613396501922
# Rovi se dispara casi un 3% en Bolsa tras aprobar EEUU un fármaco como tratamiento de la esquizofrenia 0.6910419202794219
# Paso a paso para invertir en criptomonedas y cuál es su valor 0.7194427483318
# Cómo funciona el medicamento aprobado por la FDA para tratar la hipertensión no controlada 0.5440506368264137
# El metro cuadrado de construcción ya cuesta más de un $1 millón y en un año subió 288 por ciento 1.0
# ¿Devaluar o no devaluar?: las estimaciones enfrentadas de grandes bancos extranjeros e consultoras locales 0.7167825178442498
# Jubilados ANSES: cómo saber si cobrás el bono de 70 mil pesos en abril 2024 0.9500615990306779
# Cómo llegar a fin de mes: 5 apps que ayudan a evitar los pequeños gastos que te arruinan el bolsillo 0.8638938909800062
# Más aumentos: el Gobierno desreguló el precio del pan y la yerba 1.0
# El Gobierno provincial desmereció el reclamo de los dirigentes ruralistas: "Están motivados por cuestiones políticas" 0.9046396532371404
# ¿Cuál es el país más limpio del mundo? 0.7428068592862659
# El Gobierno anticipó que modificará las escalas del Impuesto a las Ganancias 0.5489196736880497
# Dólar blue hoy en Córdoba: cuál es el valor de referencia de este lunes 1 de abril de 2024 0.7194427483318
# Qué puede pasar con los precios de la yerba tras un cambio clave que ya está vigente 0.48748135714286606
# Inversiones: para los amantes del oro qué acciones comprar 0.5711062322732856
# ¿Cuánto trabajo da la fruticultura del Valle? 1.0
# El ingreso de divisas por exportaciones del agro creció 61% en el primer trimestre 1.0
# Se viene una nueva suba de las prepagas: aumentarán 20% en abril 0.9735161347638114
# Este es el Toyota Corolla más económico del mercado - MDZ Online 0.5140313180788115
# Baja automática en el Monotributo de AFIP: qué es y cómo adherirse nuevamente 0.8195430564520284
# Dólar hoy: cuál es el precio de la moneda el 1 de abril 0.7194427483318
# Los aumentos en los servicios que llegarán en abril y que presionarán sobre la inflación 0.89742210815368
# El Banco Mundial prevé que el crecimiento de China se frenará en 2024 y en 2025 0.9487770263319408
# Ya rige la desregulación de los precios de la yerba mate: qué pasará en las góndolas 0.5376858160489583
# Buscar empleo: una tarea que no debe subestimarse 0.43385311659668435
# Plazo fijo abril 2024: ¿cuánto dinero obtengo al mes si invierto $1.100.000? 0.7024288472255104
# Atención carnívoros: ¿cómo preparar el corte con poca grasa y muy barato, ideal para diferentes recetas? | Crónica | Firme junto al pueblo 0.46081742325658
# La recaudación de tasas municipales se desplomó hasta un 35% 0.948042339577507
# Cuál es el mejor horario para tomar vitaminas 0.5387610676035662
# Aumentaron la nafta y el gasoil: cómo conseguir descuentos y reintegros de hasta $5.000 en abril 0.831026966045037
# Impuesto a las Ganancias: el Gobierno anticipó que actualizarán el piso y volvió a advertir que se podría aplicar un retroactivo 0.5677587765590822
# La infusión saludable para reemplazar el café en el desayuno y que te proporcionará todo lo que necesitás 0.4348608941805818
# Impacto del Decreto 172/2024 en la contratación de prestadores de salud: el rol de la tecnología 0.6592503310237262
# Impuesto a las Ganancias: el Gobierno advirtió a cuánto bajaría el piso mínimo 0.5557738276139137
# PAMI: qué medicamentos gratis están disponibles desde hoy para los jubilados 0.5353521426916499
# Este mes aumenta otra vez la medicina prepaga entre 16% y 19% según la prestadora 0.8904056210178256
# La regulación europea de IA, semáforos e impacto global 0.5842378324370942
# Javier Milei, sobre la dolarización: "No creo que lleguemos para las elecciones del año que viene" 0.5168645256157797
# Los medicamentos gratis que están disponibles desde hoy para los jubilados 0.48727990919392106
# ¿Qué hacer si se llega con plata extra a fin de mes? 0.7375906936869401
# De fingir demencia a pregonar coherencia 0.4404874685724792
# Argentina intensifica negociaciones para exportar gas a Brasil a través de Bolivia 0.9346838757404046
# Cómo comprar ETFs en Argentina en pesos e invertir 0.7194427483318
# Nutrí tu jardín con el poder de la zanahoria y no te arrepentirás - MDZ Online 0.5522522246509763
# Afip redujo la tasa de interés para quienes deben regularizar deudas tributarias 0.7295246818213408
# El principal banco de EEUU dice que la economía argentina caerá 3,6% este año y la inflación será del 200% 0.956838757700364
# Alemania aprueba una de las leyes de tenencia de marihuana más permisivas de Europa 0.4702046442314672
# Remedios gratis: cuáles y para quiénes 0.5109267630833902
# Almacenes en crisis: "La gente no hace compras semanales o mensuales, se lleva lo del día" 0.8638938909800062
# Por la suba de un impuesto, la nafta súper y el gasoil subieron 4,3% en Córdoba este lunes 0.4818237065058585
# -30%: a este ritmo cayó en el primer trimestre la venta de 0Km y habrá cada vez más ofertas (Jeep, a contramano) 0.910817554381108
# Nuevo mes, más aumentos: una por una, todas las subas de abril 1.0
# Barrera de la piel: por qué es tan importante y cómo debemos cuidarla 0.5353521426916499
# ¿Ganar otro sueldo con un plazo fijo?: cuánto obtengo si deposito $4.000.000 0.7414567640182718
# Los combustibles acumulan una suba de casi 200 por ciento desde que ganó Milei | Este mes volvieron a aumentar los precios un 4,6 por ciento 0.4380673197317466
# Cuánto sale Netflix Argentina con el precio del dólar hoy, lunes 1 de abril 0.7194427483318
# Caída de 3,6% en el PBI con inflación de 200%, el pronóstico de JP Morgan que celebró el Gobierno 0.7790719574311255
# Adorni anticipó que publicará datos sobre la pauta oficial: "Otra de las herencias del gobierno anterior" 0.6086824395315972
# Transición energética: Santa Fe reivindica el rol del sector público 0.46738989839995215
# Las empleadas domésticas cobran con aumento en abril: cómo quedan los sueldos 0.7102458137703297
# Impuesto a las Ganancias: cuál sería el nuevo piso mínimo 0.6207769881421864
# Dólar, plazo fijo, acciones y más: las 5 claves de la semana para saber en qué invertir 0.7346990184451018
# El viernes comienza el pago de sueldos a los estatales 0.5388837251748755
# Dólares del campo: el agro liquidó un 22% más de divisas que en marzo del año pasado 1.0
# Sorpresa en el INDEC: por qué ofertas de supermercados no influyen en la inflación 0.819401991754158
# Tras la desregulación del precio de la yerba, afirman que "se beneficiará a las grandes empresas" 0.47840362086571414
# 114

# %%
len(docs_per_topics_4[-1])
# Out:
# 191

# %% [markdown]
# - 4. Con 100 registros:
#     - sin preprocesamiento
#     - con vocabulario
#     - sin ajustes de bertopic
#     - con TFIDFVectorizer que aplica al vocabulario
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 3
#             - del topico 0, de 65 (Test 3) a 69.
#             - del topico 1, de 18 (Test 3) a 21.
#
# Cabe mencionar que la cantidad de palabras del vocabulario es de 2012 vs 2279 que se obtienen de TFIDF sobre el total de los documentos

# %% [markdown]
# ## Test 5- solo con palabras del vocabulario que se repiten mas de una vez

# %%
# Cargar el modelo de spaCy para español
spa = spacy.load("es_core_news_lg")

# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS] 

# Detectar entidades para todos los documentos usando spaCy
entities_spa = []
for doc in tqdm(data):
    extract = spa(doc)
    entities_spa.append([(ent.text, ent.label_) for ent in extract.ents])

# Procesamiento de entidades encontradas
entities = []
original_entities = []
word_count = {}
for item in tqdm(entities_spa):
    for ent in item:
        if ent[1] == 'PER' or ent[1] == 'ORG' or ent[1] == 'LOC':
            token = str(ent[0]).lower()  
            if token not in word_count:
                word_count[token] = {'count': 0, 'original': ent[0]}
                
            word_count[token]['count'] += 1   
    
    # Ordenar el diccionario por el valor del conteo en orden descendente
    sorted_word_count = dict(sorted(word_count.items(), key=lambda item: item[1]['count'], reverse=True))  

    word_count = {}

    # Crear la lista de entidades procesadas por noticia (para guardar en DB)
    original_entities.append( [value['original'] for _, value in sorted_word_count.items() 
                                if value['original'].lower() not in SPANISH_STOPWORDS_SIN_ACENTOS and len(value['original'].split()) < 5] )

    # Crear la lista de entidades procesadas por noticia (entrenamiento)
    pre_entities = clean_all( [key for key, _ in sorted_word_count.items()
                                if key not in SPANISH_STOPWORDS_SIN_ACENTOS and len(key.split()) < 5 and _['count'] > 1 ] )

    # entidades para entrenar
    entities.append( pre_entities )
# Out:
# 100%|██████████| 1000/1000 [02:16<00:00,  7.33it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1198.84it/s]

# %%
# Vocabulario
preprocessed_entities = []
registro = ""
for array in entities:
    for ent in array:
        if len(ent.split()) > 2:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:    
                    preprocessed_entities.append(word)
                elif word.isnumeric() and len(word) == 4:
                    preprocessed_entities.append(word)
        else:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:  
                    registro += word + " "
            if registro:
                preprocessed_entities.append(registro.strip())
                registro = ""

vocab_entities = list(set([item for item in preprocessed_entities]))
len(vocab_entities)
# Out:
# 2912

# %%
tfidf_vectorizer_5 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.9,
    min_df=0.1,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    vocabulary=vocab_entities,
    # max_features=100_000
)
tfidf_vectorizer_5.fit(data)

topic_model_5 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_5
)

topics_5, probs_5 = topic_model_5.fit_transform(data)

# %%
T_5 = topic_model_5.get_document_info(data)
docs_per_topics_5 = T_5.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_5
# Out:
# {-1: Index([  3,   4,  32,  43,  44,  47,  48,  51,  66,  71,
#         ...
#         929, 940, 945, 946, 948, 962, 964, 968, 974, 998],
#        dtype='int64', length=146),
#  0: Index([ 23,  39,  82,  93,  95,  99, 101, 105, 106, 119,
#         ...
#         952, 958, 963, 970, 975, 976, 979, 981, 988, 990],
#        dtype='int64', length=164),
#  1: Index([  0,  10,  12,  24,  25,  26,  34,  45,  56,  59,
#         ...
#         926, 938, 942, 950, 961, 982, 992, 993, 995, 996],
#        dtype='int64', length=137),
#  2: Index([ 13,  14,  17,  29,  49,  50,  53,  57,  89,  91,
#         ...
#         941, 943, 949, 953, 955, 960, 967, 973, 986, 999],
#        dtype='int64', length=120),
#  3: Index([  5,  18,  36,  41,  58,  63,  64,  70,  77,  79,  81,  85,  87,  90,
# 15   Bitcoin: cómo se ha movido en el mercado este 2 de abril 1.0
# 16   Google dice adiós a una de sus mejores aplicaciones después de seis años de vida 1.0
# 20   Un teclado puede albergar más gérmenes que un inodoro: qué tipo de bacterías 0.9463052421768003
# 30   Criptomonedas: el precio de ethereum para este día 1.0
# 35   Se disparó el interés por alquilar departamentos de 4 ambientes en CABA: la oferta subió más de 80 por ciento 1.0
# 37   Transición vincular: estrategias para una vida de pareja plena en la madurez 1.0
# 40   Criptomonedas: el valor de tether para este 2 de abril 1.0
# 42   Glosario de tecnología: qué son las Redes sociales 1.0
# 46   Exclusivo: con quiénes está negociando el Gobierno para conseguir los USD 15.000 millones que necesita para levantar el cepo 1.0
# 47   Café en el horno microondas: Tips para calentarlo de manera segura y sin comprometer el sabor 0.9530018636701043
# 51   En cuatro años, la yerba regulada subió más de 1300%: qué pasará con el mercado liberado 0.982253749134223
# 61   Licuadora vs motosierra: los detalles de cómo se está llevando adelante el ajuste fiscal del Gobierno de Javier Milei 1.0
# 62   "Conversaciones urgentes": explorando el futuro del medio ambiente 1.0
# 76   Cómo es Optimus, el androide de Elon Musk que podría evitar que los humanos hagan tareas aburridas 0.7535131809568022
# 96   La inteligencia artificial responde mejor si somos emocionales en nuestras preguntas, demuestra estudio 1.0
# 100   Los jefes "tóxicos" ponen en riesgo el bienestar emocional de sus empleados 0.6024755056928903
# 104   Estas son las nuevas regulaciones para vehículos pesados en EEUU que buscan combatir el cambio climático 1.0
# 114   Rovi se dispara casi un 3% en Bolsa tras aprobar EEUU un fármaco como tratamiento de la esquizofrenia 1.0
# 120   Paso a paso para invertir en criptomonedas y cuál es su valor 1.0
# 138   Autismo en adultos: la importancia de derribar los estigmas para mejorar su entendimiento 1.0
# 140   eSIM y roaming: Las diferencias clave entre estos servicios ideales para viajeros 1.0
# 146   Meta pregunta la fecha de nacimiento a los usuarios de Quest para adaptar el tipo de cuenta a su edad 0.7270059252957707
# 152   Levantamiento de ego: una peligrosa forma de ejercitarse que provocó un aumento del 33% en las lesiones craneofaciales entre 2013 y 2022 1.0
# 154   El arma más letal de los ingleses en Malvinas: cómo descifraban los mensajes en clave de Argentina casi en tiempo real 0.7995178782867323
# 165   El ranking de los salarios de los presidentes de América Latina 0.7181025539516792
# 167   Cómo funciona el medicamento aprobado por la FDA para tratar la hipertensión no controlada 0.9704382388854389
# 168   El metro cuadrado de construcción ya cuesta más de un $1 millón y en un año subió 288 por ciento 1.0
# 172   ¿Devaluar o no devaluar?: las estimaciones enfrentadas de grandes bancos extranjeros e consultoras locales 1.0
# 173   Día Mundial de Concienciación sobre el Autismo: cómo abordar esta condición en familia, la experiencia de dos padres en primera persona 1.0
# 180   Jubilados ANSES: cómo saber si cobrás el bono de 70 mil pesos en abril 2024 1.0
# 181   Instagram permite editar los mensajes directos: cuál es el tiempo límite para modificarlos 1.0
# 188   La crianza emocional, en la mira 1.0
# 192   Cómo llegar a fin de mes: 5 apps que ayudan a evitar los pequeños gastos que te arruinan el bolsillo 1.0
# 193   Más aumentos: el Gobierno desreguló el precio del pan y la yerba 1.0
# 199   Se terminó el juicio contra UFC: La empresa ganó la pelea más importante 0.8682571585550828
# 205   El Gobierno provincial desmereció el reclamo de los dirigentes ruralistas: "Están motivados por cuestiones políticas" 1.0
# 210   YPF aumentó sus combustibles en Mendoza y estos son los nuevos precios 0.6518984253049463
# 212   ¿Cuál es el país más limpio del mundo? 1.0
# 213   El Gobierno anticipó que modificará las escalas del Impuesto a las Ganancias 1.0
# 216   Desinstalalas ya: las 3 aplicaciones que más consumen batería en el celular 1.0
# 218   Dólar blue hoy en Córdoba: cuál es el valor de referencia de este lunes 1 de abril de 2024 1.0
# 225   27° Aniversario y nuevas formas de comunicar 1.0
# 240   Qué puede pasar con los precios de la yerba tras un cambio clave que ya está vigente 0.9610562377005677
# 243   Inversiones: para los amantes del oro qué acciones comprar 1.0
# 259   La nafta volvió a aumentar esta medianoche y en cuatro meses acumula una suba del 106% 0.6374064180406633
# 268   ¿Cuánto trabajo da la fruticultura del Valle? 1.0
# 274   Primer caso en la era Milei: importaron 4 millones de litros de vino y hay polémica con los productores 0.6617597709850515
# 276   El ingreso de divisas por exportaciones del agro creció 61% en el primer trimestre 1.0
# 298   Spotify lanza una nueva opción de suscripción para audiolibros: cuánto cuestan y dónde se puede acceder 1.0
# 304   Acceso Digital 1.0
# 316   Se viene una nueva suba de las prepagas: aumentarán 20% en abril 1.0
# 320   Este es el Toyota Corolla más económico del mercado - MDZ Online 0.978143372811201
# 326   Baja automática en el Monotributo de AFIP: qué es y cómo adherirse nuevamente 1.0
# 335   Dólar hoy: cuál es el precio de la moneda el 1 de abril 1.0
# 338   Los aumentos en los servicios que llegarán en abril y que presionarán sobre la inflación 1.0
# 342   El Banco Mundial prevé que el crecimiento de China se frenará en 2024 y en 2025 1.0
# 346   Ya rige la desregulación de los precios de la yerba mate: qué pasará en las góndolas 0.9927931390374348
# 350   Buscar empleo: una tarea que no debe subestimarse 0.7118900867557965
# 353   Plazo fijo abril 2024: ¿cuánto dinero obtengo al mes si invierto $1.100.000? 1.0
# 355   La regla de las 5 horas: la clave del éxito de Bill Gates y Elon Musk 0.7092424576171374
# 357   Atención carnívoros: ¿cómo preparar el corte con poca grasa y muy barato, ideal para diferentes recetas? | Crónica | Firme junto al pueblo 0.9917893973416423
# 360   Confirmado: el cerebro humano es cada vez más grande 1.0
# 380   La recaudación de tasas municipales se desplomó hasta un 35% 1.0
# 381   Cuál es el mejor horario para tomar vitaminas 1.0
# 383   Hackearon el sistema informático del municipio de Morón y piden dinero para liberar los datos 0.7657688262787539
# 388   Aumentaron la nafta y el gasoil: cómo conseguir descuentos y reintegros de hasta $5.000 en abril 1.0
# 397   Impuesto a las Ganancias: el Gobierno anticipó que actualizarán el piso y volvió a advertir que se podría aplicar un retroactivo 1.0
# 399   La IA de OpenAI solo necesita 15 segundos de audio para clonar una voz 1.0
# 412   Extraordinario hallazgo en Japón: en 500 años todos tendrán el mismo apellido - MDZ Online 0.9934455252050896
# 414   El fuerte descargo de una diputada provincial tras la flexibilización de las importaciones de vino - MDZ Online 0.6675169154899745
# 774   Una Ciudad abandonada, un Barrio inseguro: Vuelve el delito a Recoleta en medio del colapso del modelo del PRO - La Derecha Diario 0.5942341424585127
# 780   Alemania aprueba una de las leyes de tenencia de marihuana más permisivas de Europa 1.0
# 783   Remedios gratis: cuáles y para quiénes 0.8749647777570996
# 785   Cómo esta empresa editorial argentina sobrevive al ocaso del papel 1.0
# 788   ¿CÓMO QUEDARON LOS PRECIOS DE LOS COMBUSTIBLES EN BAHÍA BLANCA? 0.6077924333210413
# 791   Test viral: la mancha de café que elijas revelará detalles ocultos de tu personalidad 1.0
# 793   Almacenes en crisis: "La gente no hace compras semanales o mensuales, se lleva lo del día" 1.0
# 798   AUH: cuándo cobro la Asignación por Hijo de abril si mi DNI termina en 1 0.9584906266230409
# 799   Las 5 mujeres más poderosas, pero poco conocidas en el mundo de los negocios 0.6202052295042776
# 806   Por la suba de un impuesto, la nafta súper y el gasoil subieron 4,3% en Córdoba este lunes 0.7998267907456224
# 818   -30%: a este ritmo cayó en el primer trimestre la venta de 0Km y habrá cada vez más ofertas (Jeep, a contramano) 1.0
# 828   Nuevo mes, más aumentos: una por una, todas las subas de abril 1.0
# 830   AFIP investiga tu dinero en Mercado Pago en abril: desde cuánto y en qué transacciones 0.9251562421183765
# 839   Covid: el documental bonaerense traerá la historia oficial de una crisis que estuvo dominada por el cerrojo informativo 0.7029143280797786
# 851   Barrera de la piel: por qué es tan importante y cómo debemos cuidarla 1.0
# 856   La verdadera razón detrás del último cambio en el menú de WhatsApp 1.0
# 859   ¿Ganar otro sueldo con un plazo fijo?: cuánto obtengo si deposito $4.000.000 1.0
# 871   Un nuevo portal para sacar turnos médicos en hospitales bonaerenses 1.0
# 875   Los combustibles acumulan una suba de casi 200 por ciento desde que ganó Milei | Este mes volvieron a aumentar los precios un 4,6 por ciento 0.7038208622060405
# 886   Cuánto sale Netflix Argentina con el precio del dólar hoy, lunes 1 de abril 1.0
# 888   ¿Usar WiFi durante un viaje en avión es seguro o no? : qué dice la ciencia 1.0
# 889   Caída de 3,6% en el PBI con inflación de 200%, el pronóstico de JP Morgan que celebró el Gobierno 1.0
# 895   El paraíso de los croissant, en Córdoba: el tentador emprendimiento que es furor en redes 0.652050968783617
# 902   Adorni anticipó que publicará datos sobre la pauta oficial: "Otra de las herencias del gobierno anterior" 1.0
# 909   Transición energética: Santa Fe reivindica el rol del sector público 0.6957066817800432
# 910   Las empleadas domésticas cobran con aumento en abril: cómo quedan los sueldos 1.0
# 912   Impuesto a las Ganancias: cuál sería el nuevo piso mínimo 1.0
# 932   Dólar, plazo fijo, acciones y más: las 5 claves de la semana para saber en qué invertir 1.0
# 936   Los 10 "trucos secretos" que te facilitan la vida con Gmail, a 20 años de su lanzamiento 1.0
# 946   Alemania legalizó el consumo recreativo de cannabis en medio de una intensa polémica 1.0
# 954   Los 4 consejos del Feng Shui para que los muebles heredados no afecten la energía de tu casa 1.0
# 964   El viernes comienza el pago de sueldos a los estatales 1.0
# 968   "Un estafador nos engañó por Facebook Marketplace y se metió en nuestra casa" - MDZ Online 0.8397842559175944
# 969   Dólares del campo: el agro liquidó un 22% más de divisas que en marzo del año pasado 1.0
# 974   AUH: cuándo cobro la Asignación por Hijo de abril si mi DNI termina en 2 0.9371073033526781
# 997   Sorpresa en el INDEC: por qué ofertas de supermercados no influyen en la inflación 1.0
# 998   Tras la desregulación del precio de la yerba, afirman que "se beneficiará a las grandes empresas" 0.981102683474878
# 184

# %%
topico = 1
for doc in docs_per_topics_5[topico]:
    print(doc," ",data_title[doc], probs_5[doc])
len(docs_per_topics_5[topico])
# Out:
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 0.9661419491708247
# 82   Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.7946129226210314
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# 95   La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 0.9679645494820338
# 99   Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.6076370799111283
# 101   ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.4318192464758482
# 105   La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 1.0
# 106   El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 1.0
# 119   Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 0.9199324305977111
# 137   River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# 150   Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# 158   Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.6368719039797549
# 170   El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.7681408507622542
# 174   La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# 176   Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# 178   En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 0.8251041693116108
# 186   River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 0.9741083826179556
# 187   De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# 189   Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 194   Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 0.8135109455524813
# 204   CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# 208   Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# 214   Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# 220   Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# 221   Sinner extiende un año colosal en Miami 0.7743417230906725
# 222   Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# 230   Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 1.0
# 239   Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# 244   "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# 257   Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# 261   Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.8517101039818242
# 265   Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# 269   Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.7000564825052431
# 270   Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 0.8330987480113647
# 271   Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.4628938554317952
# 275   El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# 277   Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# 278   Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 1.0
# 281   Tras una odisea, River llegó a Venezuela 1.0
# 282   Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 285   Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 0.9612704254626007
# 287   Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.7736402286221287
# 307   Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.9877637845637738
# 319   LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.49062419413876845
# 324   Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.7144860351501942
# 325   Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# 356   Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# 358   Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.7869075650828429
# 361   Internaron a Cesar Luis Menotti y crece la preocupación 0.6438906426548167
# 362   Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# 364   Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# 377   Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# 378   El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# 379   Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.8184067966774833
# 392   Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# 405   Cagliari empata el juego ante Hellas Verona 1.0
# 409   La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# 415   "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# 423   Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.7093268488907647
# 426   Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# 431   Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# 448   Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.8218871042306769
# 449   Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# 454   El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# 457   Racing tuvo un día libre mientras disfruta de un presente bárbaro 0.9415858461232626
# 460   Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 1.0
# 474   Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# 475   Udinese visita a Sassuolo por la fecha 30 0.8837568065447686
# 486   Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# 491   Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.7522788988069513
# 495   Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# 503   ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# 507   El jujeño Calderari recibió el "ok" de Zielinski en Lanús 0.9116175331117063
# 510   Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# 511   Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 0.9693243331171526
# 513   Godoy Cruz visita a Platense para quedar como único líder 0.750940163641465
# 526   Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# 527   Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# 530   Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# 533   Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# 539   El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# 547   Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# 559   Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 0.9538956383593598
# 568   River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# 570   Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 576   Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# 577   Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# 578   Mungo, goleadora pero con las manos vacías con Ardoi 0.970650124603464
# 581   Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# 585   La historia de Central en sus debuts en la Copa Libertadores 1.0
# 591   Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# 601   Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 627   Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# 630   La rosarina Nadia Podoroska ganó su segundo título WTA en México 0.8482881964150975
# 636   (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# 637   ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.6772631369374451
# 639   Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 0.9663273529116451
# 656   Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# 664   De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 1.0
# 675   Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.8676496083110325
# 683   ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 689   Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.7099281311025034
# 690   Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# 691   Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# 695   Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# 696   El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# 706   Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# 718   Un ex funcionario de Ucrania predijo que Zelenski será "un don nadie" 0.6297534647233312
# 719   La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# 722   Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.9321846719667373
# 725   La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# 726   Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 0.986098608452481
# 733   Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# 739   Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# 742   Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.7601540268071971
# 748   Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.9862294241042573
# 749   Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 0.9793232937954202
# 750   Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# 754   ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 756   Walter Perazzo: "Hicimos méritos para el empate" 1.0
# 762   Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# 765   Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# 784   La lista de Belgrano para su debut internacional, con un par de regresos importantes 0.9369412462486612
# 792   Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# 808   El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# 813   Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# 816   Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# 831   Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.970650124603464
# 836   Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.8255120367389123
# 838   Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 1.0
# 841   Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# 845   Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# 849   Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# 852   Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 1.0
# 855   Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 1.0
# 857   Los 10 datos más curiosos en la historia de la NBA 0.5075118753769456
# 874   La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# 878   Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 0.987436958503168
# 894   La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# 903   Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# 904   Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# 906   Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# 908   Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.7697598900355022
# 914   Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 923   Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# 925   Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 0.8759891561442404
# 930   Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# 947   La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 0.9307039826247914
# 952   Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 0.9845745540764638
# 958   ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# 963   Gabigol en otra polémica: su continuidad en Flamengo 0.7249256637501684
# 970   El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 1.0
# 975   Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# 976   Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# 979   Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# 981   Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# 988   El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# 990   La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 159

# %%
len(docs_per_topics_5[-1])
# Out:
# 146

# %% [markdown]
# - 5. Con 100 registros:
#     - sin preprocesamiento
#     - con vocabulario + repeticion de palabras: mas de una vez
#     - sin ajustes de bertopic
#     - con TFIDFVectorizer que aplica al vocabulario
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 4
#             - del topico 0, de 69 (Test 4) a 50.
#             - del topico 1, de 21 (Test 4) a 16.
#
# Cabe mencionar que la cantidad de palabras del vocabulario es de 543 vs 2279 que se obtienen de TFIDF sobre el total de los documentos

# %% [markdown]
# ## Test 6- solo con palabras del vocabulario que se repiten mas de dos veces

# %%
# Cargar el modelo de spaCy para español
spa = spacy.load("es_core_news_lg")

# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS] 

# Detectar entidades para todos los documentos usando spaCy
entities_spa = []
for doc in tqdm(data):
    extract = spa(doc)
    entities_spa.append([(ent.text, ent.label_) for ent in extract.ents])

# Procesamiento de entidades encontradas
entities = []
original_entities = []
word_count = {}
for item in tqdm(entities_spa):
    for ent in item:
        if ent[1] == 'PER' or ent[1] == 'ORG' or ent[1] == 'LOC':
            token = str(ent[0]).lower()  
            if token not in word_count:
                word_count[token] = {'count': 0, 'original': ent[0]}
                
            word_count[token]['count'] += 1   
    
    # Ordenar el diccionario por el valor del conteo en orden descendente
    sorted_word_count = dict(sorted(word_count.items(), key=lambda item: item[1]['count'], reverse=True))  

    word_count = {}

    # Crear la lista de entidades procesadas por noticia (para guardar en DB)
    original_entities.append( [value['original'] for _, value in sorted_word_count.items() 
                                if value['original'].lower() not in SPANISH_STOPWORDS_SIN_ACENTOS and len(value['original'].split()) < 5] )

    # Crear la lista de entidades procesadas por noticia (entrenamiento)
    pre_entities = clean_all( [key for key, _ in sorted_word_count.items()
                                if key not in SPANISH_STOPWORDS_SIN_ACENTOS and len(key.split()) < 5 and _['count'] > 2 ] )

    # entidades para entrenar
    entities.append( pre_entities )
# Out:
# 100%|██████████| 1000/1000 [01:34<00:00, 10.56it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2772.46it/s]

# %%
# Vocabulario
preprocessed_entities = []
registro = ""
for array in entities:
    for ent in array:
        if len(ent.split()) > 2:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:    
                    preprocessed_entities.append(word)
                elif word.isnumeric() and len(word) == 4:
                    preprocessed_entities.append(word)
        else:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:  
                    registro += word + " "
            if registro:
                preprocessed_entities.append(registro.strip())
                registro = ""

vocab_entities = list(set([item for item in preprocessed_entities]))
len(vocab_entities)
# Out:
# 1320

# %%
tfidf_vectorizer_6 = TfidfVectorizer(
    # tokenizer=tokenizer,
    # max_df=0.8,
    # min_df=0.2,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    vocabulary=vocab_entities,
    # max_features=100_000
)
tfidf_vectorizer_6.fit(data)

topic_model_6 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_6
)

topics_6, probs_6 = topic_model_6.fit_transform(data)

# %%
T_6 = topic_model_6.get_document_info(data)
docs_per_topics_6 = T_6.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_6
# Out:
# {-1: Index([  3,   4,  10,  20,  21,  22,  24,  25,  26,  28,
#         ...
#         945, 946, 948, 955, 962, 964, 974, 982, 993, 998],
#        dtype='int64', length=245),
#  0: Index([ 23,  39,  82,  93,  95,  99, 101, 105, 106, 119,
#         ...
#         952, 958, 963, 970, 975, 976, 979, 981, 988, 990],
#        dtype='int64', length=163),
#  1: Index([ 13,  14,  17,  29,  49,  50,  53,  89,  91, 107,
#         ...
#         934, 941, 943, 949, 953, 960, 967, 973, 986, 999],
#        dtype='int64', length=110),
#  2: Index([  5,  18,  36,  41,  58,  63,  64,  66,  70,  77,  79,  81,  85,  87,
#          90,  94,  98, 113, 115, 116, 118, 122, 125, 141, 143, 144, 147, 156,
#         196, 215, 219, 235, 250, 286, 291, 299, 315, 318, 321, 323, 347, 351,
#         366, 374, 384, 390, 400, 403, 437, 440, 441, 451, 469, 481, 485, 496,
#         538, 553, 555, 560, 565, 567, 573, 605, 608, 617, 626, 669, 672, 712,
#         732, 741, 771, 776, 786, 820, 823, 829, 848, 862, 891, 913, 917, 922,
#         927, 935, 951, 959, 971, 977, 983, 984, 987, 989],
#        dtype='int64'),
#  3: Index([  1,   6,   9,  35,  46, 104, 114, 168, 172, 180, 192, 193, 205, 212,
#         268, 276, 316, 326, 338, 342, 353, 380, 388, 436, 461, 466, 483, 484,
#         499, 518, 540, 562, 566, 587, 594, 604, 619, 628, 638, 646, 659, 671,
#         678, 679, 681, 699, 708, 757, 758, 764, 773, 793, 806, 818, 828, 859,
#         889, 902, 910, 932, 969, 997],
#        dtype='int64'),
#  4: Index([  7,  11,  16,  37,  42,  62,  96, 138, 140, 152, 173, 181, 188, 216,
#         225, 298, 304, 360, 399, 433, 455, 497, 535, 550, 563, 609, 631, 694,
#         746, 753, 766, 785, 791, 856, 888, 936, 954, 968],
#        dtype='int64'),
#  5: Index([ 59, 111, 195, 202, 206, 237, 280, 293, 343, 398, 402, 421, 442, 456,
#         473, 493, 520, 531, 548, 600, 642, 658, 673, 720, 723, 790, 825, 853,
#         870, 873, 911, 919, 938, 942, 992],
#        dtype='int64'),
#  6: Index([ 33,  60, 200, 231, 238, 248, 262, 289, 302, 314, 328, 427, 429, 430,
#         445, 480, 501, 561, 583, 620, 623, 624, 651, 687, 716, 751, 752, 778,
#         805, 887, 972],
#        dtype='int64'),
#  7: Index([191, 246, 279, 303, 312, 345, 372, 434, 506, 521, 529, 649, 692, 713,
#         727, 728, 761, 769, 770, 809, 822, 854, 876, 896, 931, 980],
#        dtype='int64'),
#  8: Index([ 19,  27,  38, 103, 132, 133, 171, 228, 245, 258, 311, 339, 352, 375,
#         477, 500, 508, 536, 676, 701, 814, 860, 861, 898, 956],
#        dtype='int64'),
#  9: Index([ 55,  68, 112, 139, 177, 227, 266, 290, 331, 332, 368, 406, 579, 590,
#         640, 645, 657, 735, 794, 812, 815, 832, 890, 944, 994],
#        dtype='int64'),
#  10: Index([  8,  52,  67,  72, 123, 151, 182, 201, 226, 288, 292, 340, 464, 532,
#         603, 654, 885, 918, 928, 933, 957, 978],
#        dtype='int64'),
#  11: Index([ 31,  54, 110, 247, 267, 296, 297, 301, 363, 401, 443, 462, 709, 721,
#         738, 768, 835, 881, 939, 965],
#        dtype='int64'),
#  12: Index([102, 175, 209, 294, 305, 341, 344, 373, 391, 467, 516, 602, 655, 667,
#         772, 811, 865, 868, 893],
#        dtype='int64'),
#  13: Index([  0,  12, 121, 142, 283, 418, 487, 525, 542, 546, 589, 598, 863, 867,
#         901, 950, 995, 996],
#        dtype='int64'),
#  14: Index([ 56,  65,  80, 108, 124, 130, 207, 256, 300, 376, 407, 410, 425, 571,
#         647, 665, 804, 961],
#        dtype='int64'),
#  15: Index([136, 162, 223, 254, 354, 359, 420, 505, 517, 574, 907, 966, 991], dtype='int64'),
#  16: Index([2, 32, 83, 92, 149, 163, 184, 211, 365, 661, 693, 775, 883], dtype='int64'),
#  17: Index([264, 333, 369, 515, 648, 688, 724, 747, 843, 884, 920, 985], dtype='int64'),
#  18: Index([15, 30, 40, 120, 218, 335, 554, 599, 625, 644, 886], dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_6[topico]:
    print(doc," ",data_title[doc], probs_6[doc])
len(docs_per_topics_6[topico])
# Out:
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 1.0
# 82   Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.756463433014935
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# 95   La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 0.759026333039102
# 99   Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.5267177672842149
# 101   ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.4062603559164919
# 105   La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 0.9691739027421016
# 106   El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 0.9992020231770404
# 119   Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 0.9434298252237105
# 137   River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# 150   Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# 158   Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.7994996981201222
# 170   El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.6617818460952919
# 174   La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 0.9632968014127972
# 176   Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# 178   En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 0.9192997412664712
# 186   River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 0.8987560347464321
# 187   De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# 189   Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 194   Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 0.8673212649025503
# 204   CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# 208   Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# 214   Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# 220   Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# 221   Sinner extiende un año colosal en Miami 0.6105513961792584
# 222   Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# 230   Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 0.8916769590408538
# 239   Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# 244   "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# 257   Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# 261   Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.6736832178410395
# 265   Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# 269   Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.4863426002101957
# 270   Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 0.7808408577138914
# 271   Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.5034229679192517
# 275   El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# 277   Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# 278   Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 0.88338806005808
# 281   Tras una odisea, River llegó a Venezuela 1.0
# 282   Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 285   Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# 287   Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.9347529899932044
# 307   Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.7441350434329087
# 319   LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.5496158758937104
# 324   Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.8350045239421994
# 325   Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# 348   Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.4053175975303847
# 356   Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# 358   Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.7999654075297296
# 361   Internaron a Cesar Luis Menotti y crece la preocupación 0.5124684246315139
# 362   Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# 364   Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# 377   Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# 378   El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# 379   Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 0.8673212649025503
# 387   Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.45883722045921377
# 392   Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# 405   Cagliari empata el juego ante Hellas Verona 0.990253819936026
# 408   La razón por la que Alemania sacó de circulación camiseta con el número 44 0.43391520070759415
# 409   La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# 415   "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# 423   Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.8568682286623777
# 426   Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# 431   Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# 448   Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.8673212649025503
# 449   Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# 454   El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# 457   Racing tuvo un día libre mientras disfruta de un presente bárbaro 0.8903596909177409
# 460   Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 0.8680199147926069
# 474   Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# 475   Udinese visita a Sassuolo por la fecha 30 0.8348714375801908
# 486   Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 1.0
# 491   Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.7439817076492713
# 495   Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# 503   ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# 507   El jujeño Calderari recibió el "ok" de Zielinski en Lanús 0.8215911836732678
# 510   Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# 511   Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 0.9422943868142089
# 513   Godoy Cruz visita a Platense para quedar como único líder 0.718571594448059
# 526   Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# 527   Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# 530   Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# 533   Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# 539   El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# 547   Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# 559   Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 0.7863389834129715
# 568   River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# 569   Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.4439707794737779
# 570   Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 576   Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# 577   Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 0.9994099329586272
# 578   Mungo, goleadora pero con las manos vacías con Ardoi 0.8673212649025503
# 581   Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# 585   La historia de Central en sus debuts en la Copa Libertadores 1.0
# 591   Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# 601   Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 614   La Selección alemana cambia su camiseta por una similitud con el logo de la SS | ¿Qué pasó con el nuevo diseño de Adidas? 0.4314765593962001
# 627   Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# 630   La rosarina Nadia Podoroska ganó su segundo título WTA en México 0.7926969156880324
# 636   (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# 637   ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.8433648846530621
# 639   Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 1.0
# 656   Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# 664   De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 0.8084431872829834
# 675   Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.8668036112112101
# 683   ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 689   Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.7184351431846256
# 690   Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# 691   Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# 695   Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# 696   El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 0.8948251311627016
# 706   Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# 719   La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# 722   Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.8878497781793123
# 725   La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# 726   Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# 733   Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 0.88338806005808
# 739   Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# 742   Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.6857345025220336
# 748   Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.8924543160693755
# 749   Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# 750   Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# 754   ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 756   Walter Perazzo: "Hicimos méritos para el empate" 1.0
# 762   Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 1.0
# 765   Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# 784   La lista de Belgrano para su debut internacional, con un par de regresos importantes 0.9116266541474283
# 792   Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# 808   El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# 813   Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# 816   Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 0.972244726085465
# 831   Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 0.8031787034730635
# 836   Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.7867548556257575
# 838   Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 0.9298081980940823
# 841   Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# 845   Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 1.0
# 849   Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# 852   Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 0.9298800454862648
# 855   Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 0.9054958584981944
# 857   Los 10 datos más curiosos en la historia de la NBA 0.6151369606752138
# 874   La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# 878   Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 1.0
# 894   La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# 903   Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# 904   Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 0.974895514033044
# 906   Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# 908   Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.6594757930763294
# 914   Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 923   Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# 925   Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 0.8515582248748429
# 930   Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# 947   La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 1.0
# 952   Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 1.0
# 958   ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# 963   Gabigol en otra polémica: su continuidad en Flamengo 0.773001986663499
# 970   El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 1.0
# 975   Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# 976   Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# 979   Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# 981   Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# 988   El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# 990   La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 163

# %%
topico = 1
for doc in docs_per_topics_6[topico]:
    print(doc," ",data_title[doc], probs_6[doc])
len(docs_per_topics_6[topico])
# Out:
# 13   Un niño de 12 años mató a un compañero de clase e hirió a otros dos con un arma de fuego en Finlandia 1.0
# 14   Accidente en la General Paz: un auto terminó incrustado debajo de un camión 1.0
# 17   Una joven de 19 años fue baleada en la puerta de su casa por dos hombres que tendrían problemas con su novio 1.0
# 29   Dead Kennedys acusó a seguidores del primer ministro húngaro de plagiar su icónica foto 1.0
# 49   Se fugó de un penal y lo atraparon los vecinos cuando quiso robar en una casa de Los Hornos: lo golpearon y desnudaron 1.0
# 50   Fin de semana sangriento en Ecuador: 137 homicidios durante el asueto de Semana Santa 1.0
# 53   Un militar venezolano fue obligado a declarar que había planificado un magnicidio con apoyo de María Corina Machado 0.8940685835354047
# 89   El video que muestra a los jugadores de Vélez salir de la habitación del hotel tras el presunto abuso sexual 0.93585690799057
# 967   Chile: la detuvieron, le quitó el arma a un guardia y empezó a los tiros 1.0
# 973   El extenso prontuario del ladrón que asaltó a una turista italiana cerca del Obelisco | Crónica | Firme junto al pueblo 1.0
# 986   Robinho preso: pasó a celda común 1.0
# 999   Tiroteo en una escuela de Finlandia: un menor murió y hay otros dos heridos 1.0
# 110

# %%
len(docs_per_topics_6[-1])
# Out:
# 245

# %% [markdown]
# - 6. Con 100 registros:
#     - sin preprocesamiento
#     - con vocabulario + repeticion de palabras: mas de dos veces
#     - sin ajustes de bertopic
#     - con TFIDFVectorizer que aplica al vocabulario
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 3
#             - del topico 0, de 65 (Test 3) a 64.
#             - del topico 1, de 18 (Test 3) a 21.
#
# Cabe mencionar que la cantidad de palabras del vocabulario es de 259 vs 2279 que se obtienen de TFIDF sobre el total de los documentos

# %% [markdown]
# ## Test 7- Palabras de vocab que se repite mas de una vez + configuracion en max_df y min_df

# %%
# Cargar el modelo de spaCy para español
spa = spacy.load("es_core_news_lg")

# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS] 

# Detectar entidades para todos los documentos usando spaCy
entities_spa = []
for doc in tqdm(data):
    extract = spa(doc)
    entities_spa.append([(ent.text, ent.label_) for ent in extract.ents])

# Procesamiento de entidades encontradas
entities = []
original_entities = []
word_count = {}
for item in tqdm(entities_spa):
    for ent in item:
        if ent[1] == 'PER' or ent[1] == 'ORG' or ent[1] == 'LOC':
            token = str(ent[0]).lower()  
            if token not in word_count:
                word_count[token] = {'count': 0, 'original': ent[0]}
                
            word_count[token]['count'] += 1   
    
    # Ordenar el diccionario por el valor del conteo en orden descendente
    sorted_word_count = dict(sorted(word_count.items(), key=lambda item: item[1]['count'], reverse=True))  

    word_count = {}

    # Crear la lista de entidades procesadas por noticia (para guardar en DB)
    original_entities.append( [value['original'] for _, value in sorted_word_count.items() 
                                if value['original'].lower() not in SPANISH_STOPWORDS_SIN_ACENTOS and len(value['original'].split()) < 5] )

    # Crear la lista de entidades procesadas por noticia (entrenamiento)
    pre_entities = clean_all( [key for key, _ in sorted_word_count.items()
                                if key not in SPANISH_STOPWORDS_SIN_ACENTOS and len(key.split()) < 5 and _['count'] > 1 ] )

    # entidades para entrenar
    entities.append( pre_entities )
# Out:
# 100%|██████████| 1000/1000 [02:02<00:00,  8.13it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1704.12it/s]

# %%
# Vocabulario
preprocessed_entities = []
registro = ""
for array in entities:
    for ent in array:
        if len(ent.split()) > 2:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:    
                    preprocessed_entities.append(word)
                elif word.isnumeric() and len(word) == 4:
                    preprocessed_entities.append(word)
        else:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS_SIN_ACENTOS:  
                    registro += word + " "
            if registro:
                preprocessed_entities.append(registro.strip())
                registro = ""

vocab_entities = list(set([item for item in preprocessed_entities]))
len(vocab_entities)
# Out:
# 2912

# %%
tfidf_vectorizer_7 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.9,
    min_df=0.05,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
Index([ 31,  54, 110, 247, 267, 296, 297, 301, 363, 401, 443, 462, 709, 721,
#         738, 768, 835, 881, 939, 965],
#        dtype='int64'),
#  12: Index([  0,  45,  97, 121, 142, 283, 418, 487, 525, 546, 589, 598, 842, 863,
#         867, 901, 950, 995, 996],
#        dtype='int64'),
#  13: Index([102, 209, 294, 305, 341, 344, 373, 391, 467, 516, 602, 655, 667, 772,
#         811, 865, 868, 893],
#        dtype='int64'),
#  14: Index([56, 65, 80, 108, 124, 130, 207, 256, 376, 407, 410, 425, 571, 647, 665,
#         804],
#        dtype='int64'),
#  15: Index([2, 83, 92, 149, 163, 184, 211, 263, 365, 367, 661, 693, 775, 883], dtype='int64'),
#  16: Index([136, 162, 223, 254, 354, 359, 420, 505, 517, 907, 966, 991], dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_7[topico]:
    print(doc," ",data_title[doc], probs_7[doc])
len(docs_per_topics_7[topico])
# Out:
# 0   Elecciones en Venezuela: María Corina Machado pidió más apoyo de Noruega para garantizar unas presidenciales libres 0.9094560383444804
# 2   Día de los veteranos de Malvinas: el impacto y las secuelas del trauma psíquico en los excombatientes 0.9482652355492277
# 4   El galante gesto de Diego Maradona con Mariana A: "Lo que hizo solo habla de su generosidad" 0.9221780009267218
# 5   Se acerca el final de Rigo: RCN confirmó la fecha del último capítulo 1.0
# 8   Chipre asegura que el corredor humanitario a Gaza se mantendrá pese a la muerte de los cooperantes de WCK 0.8878870742709135
# 12   Trias no descarta un pacto Junts-PSC tras el 12-M: "El problema es para hacer qué" 0.8291469237912014
# 13   Un niño de 12 años mató a un compañero de clase e hirió a otros dos con un arma de fuego en Finlandia 0.8665561955378658
# 14   Accidente en la General Paz: un auto terminó incrustado debajo de un camión 0.9079198318994458
# 17   Una joven de 19 años fue baleada en la puerta de su casa por dos hombres que tendrían problemas con su novio 0.8583992050125201
# 19   En el homenaje a los caídos en Malvinas, Milei convocó a una nueva era de reconciliación con las Fuerzas Armadas 1.0
# 21   Vigilia de San Andrés de Giles: las emocionantes historias de veteranos de Malvinas, las 649 antorchas y la procesión desde Luján 1.0
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 0.8722384367488056
# 24   El PP acusa a Sánchez y Begoña Gómez de "tráfico de influencias conyugal" y Bolaños dice que sus palabras son miserables 0.9136606420977786
# 26   Estados Unidos y el rol de la APEP 0.8156284154468408
# 27   Milei y Villarruel encabezarán el acto central por el 42º aniversario de la Guerra de Malvinas 0.9942734731386031
# 29   Dead Kennedys acusó a seguidores del primer ministro húngaro de plagiar su icónica foto 0.8043499708712065
# 31   Murió la escritora Maryse Condé, activista contra la esclavitud y el racismo que ganó el "Nobel alternativo" 0.8462610671845479
# 32   ¿Bloquearán los republicanos de MAGA la reconstrucción de Baltimore? 0.8308884275362652
# 33   La denuncia de María Valenzuela: "A mi hija le quitaron remedios, le pregunto a Guillermo Francella ¿qué hacemos?" 1.0
# 34   Se profundiza la crisis inmobiliaria de China: Country Garden suspendió la cotización en la bolsa de Hong Kong 0.8156476068539249
# 36   Brancusi, el artista que revolucionó la escultura, en una histórica retrospectiva en el Pompidou 0.8072464592149476
# 38   La emoción de la vicepresidenta al recordar a su padre: quién fue el héroe de Malvinas Eduardo Marcelo Villarruel 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros"
# 88   Fiscal del régimen en Venezuela la emprendió contra noticiero colombiano 0.9578164136652935
# 89   El video que muestra a los jugadores de Vélez salir de la habitación del hotel tras el presunto abuso sexual 1.0
# 90   La Princesa de Gales había donado su cabello para ayudar a niños con cáncer, varios años antes de su diagnóstico 0.8310626915623722
# 91   El régimen de Nicolás Maduro excarceló al youtuber acusado de terrorismo en Venezuela 0.923497287402212
# 92   La milagrosa historia de la Virgen de Fátima en Malvinas y los 40 años que la buscó un veterano hasta dar con ella 0.8953798762015994
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 0.8228739173448325
# 94   La Chilidrina llegó a la vecindad argentina, en la provincia de Chubut 1.0
# 95   La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 0.986117390916155
# 97   Sánchez, "horrorizado" por la muerte de trabajadores de la ONG del chef José Andrés, le traslada el apoyo del Gobierno 0.8572656217147577
# 99   Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 1.0
# 64

# %%
topico = 1
for doc in docs_per_topics_7[topico]:
    print(doc," ",data_title[doc], probs_7[doc])
len(docs_per_topics_7[topico])
# Out:
# 1   El populismo derivó en que los argentinos financien el crecimiento de los países desarrollados 1.0
# 3   La revolución del efectivo: la Generación Z redescubre el dinero antiguo para evitar la bancarrota moderna 1.0
# 6   Dólar versus inflación: ¿cuál debería ser el nivel del tipo de cambio? 1.0
# 9   Elogios de un profesor argentino que enseña en Harvard: "Para hacer progresismo hay que hacer lo que está haciendo Milei" 0.9459591183206592
# 11   WhatsApp habilitó más funciones nuevas en abril, conoce la lista 0.9962922144718224
# 15   Bitcoin: cómo se ha movido en el mercado este 2 de abril 1.0
# 16   Google dice adiós a una de sus mejores aplicaciones después de seis años de vida 0.9494901968545474
# 20   Un teclado puede albergar más gérmenes que un inodoro: qué tipo de bacterías 1.0
# 30   Criptomonedas: el precio de ethereum para este día 0.9430431696779146
# 35   Se disparó el interés por alquilar departamentos de 4 ambientes en CABA: la oferta subió más de 80 por ciento 1.0
# 40   Criptomonedas: el valor de tether para este 2 de abril 0.9459591183206592
# 42   Glosario de tecnología: qué son las Redes sociales 0.8429065935992951
# 43   El premio mayor del Powerball llegó a los 1.090 millones de dólares y extiende una racha de tres meses sin ganadores 1.0
# 46   Exclusivo: con quiénes está negociando el Gobierno para conseguir los USD 15.000 millones que necesita para levantar el cepo 1.0
# 47   Café en el horno microondas: Tips para calentarlo de manera segura y sin comprometer el sabor 1.0
# 51   En cuatro años, la yerba regulada subió más de 1300%: qué pasará con el mercado liberado 1.0
# 61   Licuadora vs motosierra: los detalles de cómo se está llevando adelante el ajuste fiscal del Gobierno de Javier Milei 0.9483099763532415
# 62   "Conversaciones urgentes": explorando el futuro del medio ambiente 0.9962922144718224
# 78   Cuánto cobra un médico residente MIR de cuarto año en la Comunidad Valenciana: sueldo base y guardias 0.8221875312999359
# 19

# %%
len(docs_per_topics_7[-1])
# Out:
# 234

# %% [markdown]
# - 7 Con 100 registros:
#     - sin preprocesamiento
#     - con vocabulario + repeticion de palabras: mas de dos veces
#     - sin ajustes de bertopic
#     - con TFIDFVectorizer que aplica al vocabulario + min_df y max_df
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 3
#             - del topico 0, de 65 (Test 3) a 64.
#             - del topico 1, de 18 (Test 3) a 19.
#
# Cabe mencionar que la cantidad de palabras del vocabulario es de 259 vs 2279 que se obtienen de TFIDF sobre el total de los documentos

# %% [markdown]
# ## Test 8- Cfg Test 6 + configuracion en max_df y min_df + preprocesado de docs

# %%
# Limpiar texto
cleaner = Cleaning_text()

docs_clean = []
for doc in data:
    clean_txt = cleaner.unicode(doc)
    clean_txt = cleaner.urls(clean_txt)
    clean_txt = cleaner.simbols(clean_txt)
    clean_txt = cleaner.accents_emojis(clean_txt)
    clean_txt = cleaner.escape_sequence(clean_txt)
    docs_clean.append(cleaner.str_lower(clean_txt))

# Eliminamos stopwords del corpus
preprocessed_data = []
registro = ""
for txt in docs_clean:
    for word in txt.split():
        if word.isalpha() and not word in SPANISH_STOPWORDS_SIN_ACENTOS:
            registro += word + " "
        elif word.isnumeric():
            registro += word + " "
    preprocessed_data.append(registro+' ')
    registro = ""

# %%
tfidf_vectorizer_8 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.9,
    min_df=0.05,
    ngram_range=(1, 2),
    stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    #vocabulary=vocab_entities,
    max_features=100_000
)
tfidf_vectorizer_8.fit(preprocessed_data)

topic_model_8 = BERTopic(
    language='spanish',
    #calculate_probabilities=True,
    vectorizer_model=tfidf_vectorizer_8
)

topics_8, probs_8 = topic_model_8.fit_transform(preprocessed_data)

# %%
T_8 = topic_model_8.get_document_info(data)
docs_per_topics_8 = T_8.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_8
# Out:
# {0: Index([  0,   1,   2,   3,   4,   5,   6,   7,   9,  10,
#         ...
#         990, 991, 992, 993, 994, 995, 996, 997, 998, 999],
#        dtype='int64', length=954),
#  1: Index([  8,  52,  67,  72, 123, 151, 182, 201, 226, 260, 288, 292, 340, 464,
#         532, 603, 654, 911, 918, 928, 933, 957, 978],
#        dtype='int64'),
#  2: Index([191, 246, 279, 303, 312, 345, 372, 434, 521, 529, 649, 692, 713, 727,
#         728, 761, 809, 822, 854, 876, 896, 931, 980],
#        dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_8[topico]:
    print(doc," ",data_title[doc], probs_8[doc])
len(docs_per_topics_8[topico])
# Out:
# 0   Elecciones en Venezuela: María Corina Machado pidió más apoyo de Noruega para garantizar unas presidenciales libres 1.0
# 1   El populismo derivó en que los argentinos financien el crecimiento de los países desarrollados 1.0
# 2   Día de los veteranos de Malvinas: el impacto y las secuelas del trauma psíquico en los excombatientes 1.0
# 3   La revolución del efectivo: la Generación Z redescubre el dinero antiguo para evitar la bancarrota moderna 1.0
# 4   El galante gesto de Diego Maradona con Mariana A: "Lo que hizo solo habla de su generosidad" 1.0
# 5   Se acerca el final de Rigo: RCN confirmó la fecha del último capítulo 1.0
# 6   Dólar versus inflación: ¿cuál debería ser el nivel del tipo de cambio? 1.0
# 7   La lectura en voz alta: clave para el desarrollo infantil en el hogar y la escuela 1.0
# 9   Elogios de un profesor argentino que enseña en Harvard: "Para hacer progresismo hay que hacer lo que está haciendo Milei" 1.0
# 10   En abril crecerá la protesta sindical: se prevé una oleada de paros que incluirá al transporte, estatales, docentes y la CGT 1.0
# 11   WhatsApp habilitó más funciones nuevas en abril, conoce la lista 1.0
# 12   Trias no descarta un pacto Junts-PSC tras el 12-M: "El problema es para hacer qué" 1.0
corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 1.0
# 159   El movimiento secesionista Texit se fortalece ante la polarización y el descontento 1.0
# 160   Donald Trump pagó la fianza de 175 millones de dólares en su juicio por fraude en Nueva York y evitó el embargo 1.0
# 161   Presidencia desmiente que Dina Boluarte haya denunciado pérdida de boleta con cuatro Rolex, pese a registro en sistema de PNP 1.0
# 162   Último día del fin de semana largo: cuál es el pronóstico del tiempo para este martes 1.0
# 163   Infografía: cómo fue el desembarco en las Islas Malvinas del 2 de abril de 1982 y qué pasó los días anteriores 1.0
# 164   Incendio en un edificio de Córdoba: los investigadores analizan si una falla eléctrica provocó el fuego 1.0
# 165   El ranking de los salarios de los presidentes de América Latina 1.0
# 167   Cómo funciona el medicamento aprobado por la FDA para tratar la hipertensión no controlada 1.0
# 168   El metro cuadrado de construcción ya cuesta más de un $1 millón y en un año subió 288 por ciento 1.0
# 169   Jota Pe Hernández quiere tumbar al superintendente de Salud nombrado por el presidente Petro 1.0
# 170   El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 1.0
# 171   Milei espera que se mantenga el descenso de la inflación en los próximos meses 1.0
# 172   ¿Devaluar o no devaluar?: las estimaciones enfrentadas de grandes bancos extranjeros e consultoras locales 1.0
# 173   Día Mundial de Concienciación sobre el Autismo: cómo abordar esta condición en familia, la experiencia de dos padres en primera persona 1.0
# 174   La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# 175   Tucumán: destinan $1.250 millones para reparar un avión sanitario 1.0
# 176   Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# 177   Con el 90% de ocupación hotelera, Termas de Río Hondo fue uno de los destinos más elegidos en Semana Santa 1.0
# 178   En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 1.0
# 179   Milei habló de cómo viven sus perros en Olivos y Conan fue tendencia en redes 1.0
# 180   Jubilados ANSES: cómo saber si cobrás el bono de 70 mil pesos en abril 2024 1.0
# 181   Instagram permite editar los mensajes directos: cuál es el tiempo límite para modificarlos 1.0
# 183   Mujer detenida por el crimen del hotelero de Junín de los Andes: fue acusada y quedó en prisión preventiva 1.0
# 184   Un día como hoy, hace 42 años, tuvo lugar la "Operación Rosario" para recuperar las Malvinas 1.0
# 185   Son pareja y vendían droga: los atraparon con 600 dosis de marihuana, cocaína y armas 1.0
# 186   River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 1.0
# 187   De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# 188   La crianza emocional, en la mira 1.0
# 189   Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 190   En el Paso Cardenal Samoré, ahora cobran para usar los baños 1.0
# 192   Cómo llegar a fin de mes: 5 apps que ayudan a evitar los pequeños gastos que te arruinan el bolsillo 1.0
# 193   Más aumentos: el Gobierno desreguló el precio del pan y la yerba 1.0
# 194   Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 1.0
# 195   Sobre la demolición de la política 1.0
# 196   Flor Vigna se quebró al hablar sobre su separación de Luciano Castro 1.0
# 197   Reabrió la estación de subte Facultad de Medicina y el miércoles cerrará una de la línea B 1.0
# 198   Con un mensaje pascual, la Iglesia manifestó preocupación por los despidos 1.0
# 199   Se terminó el juicio contra UFC: La empresa ganó la pelea más importante 1.0
# 200   Darío Barassi habló de su salud tras una complicación luego de su cirugía: "Me aconsejaron quedarme internado" 1.0
# 202   Esa obsesión llamada Estela de Carlotto | Nuevo ataque de Milei a la Presidenta de Abuelas de Plaza de Mayo 1.0
# 203   Se pasó de copas y siguió de largo en la rotonda 1.0
# 204   CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# 245   Vendimia para Todxs cerró su edición 2024 con una fiesta que reunió a 1.500 personas 1.0
# 247   Quién era María Victoria De La Mota Claverie, la esposa del golfista Emilio Domínguez que murió por dengue 1.0
# 248   Dieron de alta a Roxy Vázquez tras ser internada: "Fue un cuadro viral severo" 1.0
# 249   "Los mocos de la furia", la desigualdad jerárquica vista desde la infancia 1.0
# 250   Cómo será la extraña semana de Gran hermano: un día sí, un día no... 1.0
# 251   Están entrenando a un telescopio para encontrar vida extraterrestre 1.0
# 252   Milei volvió a cargar contra los gobernadores y dijo que juega con Conan en Olivos: el misterio del perro muerto - Big Bang! News 1.0
# 253   Horóscopo: las predicciones de Jimena La Torre para la primera semana de abril 1.0
# 254   Pronóstico: para mañana se espera un aumento de la temperatura y alerta por Zonda y sectores del Gan Mendoza 1.0
# 255   Unión convoca a asambleas de socios para el jueves 11 de abril 1.0
# 256   Despidos en Parques Nacionales: "Vienen por los recursos naturales y culturales" 1.0
# 257   Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# 258   El Gobernador homenajeo a los Veteranos de Malvinas 1.0
# 259   La nafta volvió a aumentar esta medianoche y en cuatro meses acumula una suba del 106% 1.0
# 261   Quiniela Nacional y Provincial: resultados del sábado 1 de abril 1.0
# 262   Jorge Lanata, internado: el conductor volvió a la Fundación Favaloro por un problema respiratorio 1.0
# 263   Sebastián Méndez, a fondo: "Todo eso que viviste te prepara para la próxima mierda que será tu vida" 1.0
# 264   La empresa propietaria de la Fórmula 1 compra Moto GP 1.0
# 265   Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# 266   Día de la Donación de Médula Ósea: lanzan una colecta de sangre 1.0
# 267   Jaime López Rivarola sobre el fallecimiento de la esposa de Emilio Domínguez: "Queremos que sepa que todos sus amigos están pensando en él" 1.0
# 268   ¿Cuánto trabajo da la fruticultura del Valle? 1.0
# 269   Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 1.0
# 270   Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 1.0
# 271   Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 1.0
# 272   Policía Bonaerense: Una red de corrupción recaudaría más de 13 millones mensuales 1.0
# 273   Crisis en Perú por el escándalo de los Rolex de la presidenta: renunció el ministro del Interior 1.0
# 274   Primer caso en la era Milei: importaron 4 millones de litros de vino y hay polémica con los productores 1.0
# 275   El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# 276   El ingreso de divisas por exportaciones del agro creció 61% en el primer trimestre 1.0
# 277   Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# 278   Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 1.0
# 280   Por dólar planchado, Argentina deja de ser una "ganga" para los turistas extranjeros 1.0
# 281   Tras una odisea, River llegó a Venezuela 1.0
# 282   Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 283   La Cancillería acordó el regreso del embajador de Colombia tras el cruce entre Petro y Milei 1.0
# 284   Tras la fuga de San Telmo, se escaparon otros dos presos de una comisaria de Balvanera 1.0
# 285   Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# 286   Tercer encuentro de la Varieté Villa Mitre 1.0
# 287   Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera
sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# 895   El paraíso de los croissant, en Córdoba: el tentador emprendimiento que es furor en redes 1.0
# 897   Bitácora Malvinas: un programa imperdible para los amantes de la historia 1.0
# 898   Dinelli, el sacerdote por el Tercer Mundo secuestrado y exiliado que nunca declaró 1.0
# 899   Video: repartidores atraparon a un ladrón, lo golpearon y recuperaron una moto robada 1.0
# 900   Insólito: un preso pidió ir al baño y se fugó 1.0
# 901   ¿Por qué no te vas a vivir a Cuba? 1.0
# 902   Adorni anticipó que publicará datos sobre la pauta oficial: "Otra de las herencias del gobierno anterior" 1.0
# 903   Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# 904   Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# 905   Cuarto aumento de la nafta en lo que va de 2024: a cuánto se fue en Rosario 1.0
# 906   Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 1.0
# 907   Clima en Córdoba: fuerte descenso de la temperatura para el lunes, ¿llega la lluvia? 1.0
# 908   Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 1.0
# 909   Transición energética: Santa Fe reivindica el rol del sector público 1.0
# 910   Las empleadas domésticas cobran con aumento en abril: cómo quedan los sueldos 1.0
# 912   Impuesto a las Ganancias: cuál sería el nuevo piso mínimo 1.0
# 913   Cuál es el thriller de acción sudafricano que llegó a Netflix y es ideal para el fin de semana 1.0
# 914   Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 915   Trabajó de enfermera en Malvinas, la negaron como veterana y hoy sigue luchando por ser reconocida - MDZ Online 1.0
# 916   Las isleñas que hablan de Malvinas y Argentina 1.0
# 917   Tini Stoessel contó cuándo saldrá la canción que le dedicará a su papá - MDZ Online 1.0
# 919   Francos le respondió a Pullaro tras su cuestionamiento por el ajuste a los pobres: "Lo están sufriendo como todos los argentinos" 1.0
# 920   Liga Argentina de Básquetbol | Últimas noticias El Tribuno 0.2751648312848478
# 921   Mujer aprehendida por golpear a su hija en Trancas: intervienen autoridades judiciales y de protección infantil 1.0
# 922   El horrible comentario de Furia sobre el físico de Catalina en Gran Hermano 1.0
# 923   Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# 924   Cómo hacer el ritual de tierra negra y azúcar para eliminar la mala suerte 1.0
# 925   Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# 926   Reabrió la estación Facultad de Medicina de la Línea D de subtes 1.0
# 927   Mia Khalifa festejó las Pascuas disfrazada de conejita y el resultado fue polémico 1.0
# 929   Horóscopo Chino: los 3 signos que obtendrán la riqueza absoluta pronto 1.0
# 930   Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# 932   Dólar, plazo fijo, acciones y más: las 5 claves de la semana para saber en qué invertir 1.0
# 934   Brasil: ¿Bolsonaro buscará refugio en la misión diplomática argentina? | No descartan otro intento de fuga del expresidente 1.0
# 935   Shannen Doherty contó cómo se prepara para morir por el cáncer terminal que sufre 1.0
# 936   Los 10 "trucos secretos" que te facilitan la vida con Gmail, a 20 años de su lanzamiento 1.0
# 937   Indignación por 24 árboles talados en Chacras: la explicación oficial de la "masacre" que denuncian los vecinos - MDZ Online 1.0
# 603   Fue atacada la embajada de Irán en Siria y responsabilizan del bombardeo a aviones israelíes – frente a Cano 1.0
# 654   Un bombardeo de Israel mata a siete trabajadores humanitarios y crece la tensión 0.5847731993612619
# 885   Atentado en Israel: un terrorista palestino acuchilló a un niño y fue abatido por la policía - MDZ Online 0.3768924965716538
# 911   Así quedó el hospital de Al-Shifa, el más grande de Gaza, tras la retirada de Israel 0.2719558886741067
# 918   Un ataque aéreo israelí destruyó edificio del consulado de Irán en Damasco 1.0
# 928   Miles de israelíes pidieron por segunda noche consecutiva la salida de Netanyahu | Culpan al primer ministro por no liberar a los 130 rehenes en poder de Hamas 0.5303837988505863
# 933   Dos generales de la Guardia Revolucionaria y otras 6 personas murieron tras un ataque israelí contra el consulado de Irán en Damasco 0.7008707480694213
# 957   Bombardeo de Israel a la embajada de Irán en Siria mata a 8 personas 1.0
# 978   Israel bombardea la capital de Siria: hay seis muertos 0.7639355539059238
# 25

# %% [markdown]
# - 8 Con 1000 registros:
#     - con preprocesamiento de docs y stop-words
#     - con vocabulario + repeticion de palabras: mas de una vez
#     - sin ajustes de bertopic
#     - con TFIDFVectorizer que aplica al vocabulario + min_df y max_df
#         - Resultado: Clasifica en dos topicos tambien, se obtiene un resultado similar al Test 3
#             - del topico 0, de 50 (Test 5) a 48.
#             - del topico 1, de 16 (Test 5) a 18.
#
# Cabe mencionar que la cantidad de palabras del vocabulario es de 259 vs 2279 que se obtienen de TFIDF sobre el total de los documentos

# %% [markdown]
# ### Resumen
#
# |       | Test1 | Test2 | Test3 | Test4 | Test5 | Test6 | Test7 | Test8 |
# |-------|-------|-------|-------|-------|-------|-------|-------|-------|
# | Topico 0   |  71  |   61 |   65 |   69 |   50 |   64 |   64 |   48 |
# | Topico 1   |  21  |   19 |   18 |   21 |   16 |   21 |   19 |   18 |
# |  Topico -1 |  8   |   20 |   17 |   10 |   34 |   15 |   17 |   34 |
# |  Vocab |     |   2279 |    |    |   543|   259 |   259|   259 |
# |  Tiempo  seg  | 18.5 | 21.7 | 23.6 | 33.2 | 27.1 | 19.7 | 26.1 | 25.7 |

# %% [markdown]
# ## Test 9- Test 5 (solo con palabras del vocabulario que se repiten mas de una vez) + cfg BERTopic

# %%
# Cargar el modelo de spaCy para español
spa = spacy.load("es_core_news_lg")

# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)

# Detectar entidades para todos los documentos usando spaCy
entities_spa = []
for doc in tqdm(data):
    extract = spa(doc)
    entities_spa.append([(ent.text, ent.label_) for ent in extract.ents])

# Procesamiento de entidades encontradas
entities = []
word_count = {}
for item in tqdm(entities_spa):
    for ent in item:
        if ent[1] == 'PER' or ent[1] == 'ORG' or ent[1] == 'LOC':
            token = str(ent[0]).lower()  
            if token not in word_count:
                word_count[token] = {'count': 0, 'original': ent[0]}
                
            word_count[token]['count'] += 1   
    
    # Ordenar el diccionario por el valor del conteo en orden descendente
    sorted_word_count = dict(sorted(word_count.items(), key=lambda item: item[1]['count'], reverse=True))  

    word_count = {}

    # Crear la lista de entidades procesadas por noticia (entrenamiento)
    pre_entities = clean_all( [key for key, _ in sorted_word_count.items()
                                if key not in SPANISH_STOPWORDS and len(key.split()) < 5 and _['count'] > 1 ] )

    # entidades para entrenar
    entities.append( pre_entities )
# Out:
# 100%|██████████| 1000/1000 [02:48<00:00,  5.92it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2930.26it/s]

# %%
sorted_word_count
# Out:
# {'policía': {'count': 5, 'original': 'Policía'},
#  'vantaa': {'count': 2, 'original': 'Vantaa'},
#  'viertola': {'count': 2, 'original': 'Viertola'},
#  'reuters': {'count': 2, 'original': 'Reuters'},
#  'finlandia': {'count': 1, 'original': 'Finlandia'},
#  'aeropuerto de helsinki-vantaa': {'count': 1,
#   'original': 'aeropuerto de Helsinki-Vantaa'},
#  'newsletters de la nueva': {'count': 1,
#   'original': 'Newsletters de La Nueva'},
#  'interior': {'count': 1, 'original': 'Interior'},
#  'mari rantanen': {'count': 1, 'original': 'Mari Rantanen'},
#  'siltamaki': {'count': 1, 'original': 'Siltamaki'},
#  'rato': {'count': 1, 'original': 'Rato'}}

# %%
# Vocabulario
preprocessed_entities = []
registro = ""
for array in entities:
    for ent in array:
        if len(ent.split()) > 2:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS:    
                    preprocessed_entities.append(word)
                elif word.isnumeric() and len(word) == 4:
                    preprocessed_entities.append(word)
        else:
            for word in ent.split():
                if word.isalpha() and len(word) > 2 and len(word) < 15 and word not in SPANISH_STOPWORDS:  
                    registro += word + " "
            if registro:
                preprocessed_entities.append(registro.strip())
                registro = ""

vocab_entities = list(set([item for item in preprocessed_entities]))
len(vocab_entities)
# Out:
# 2914

# %%
tfidf_vectorizer_9 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.9,
    min_df=0.1,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    vocabulary=vocab_entities,
    # max_features=100_000
)
tfidf_vectorizer_9.fit(data)

# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')
# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
# Step 4 - Tokenize topics
vectorizer_model = tfidf_vectorizer_9
# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer()
# Step 6 - (Optional) Fine-tune topic representations with a `bertopic.representation` model
representation_model = KeyBERTInspired()

# All steps together
topic_model_9 = BERTopic(
  embedding_model=embedding_model,            # Step 1 - Extract embeddings
  umap_model=umap_model,                      # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,                # Step 3 - Cluster reduced embeddings
  vectorizer_model=tfidf_vectorizer_9,          # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                  # Step 5 - Extract topic words
  representation_model=representation_model,  # Step 6 - (Optional) Fine-tune topic represenations
  language='spanish',
  #calculate_probabilities=True
)

topics_9, probs_9 = topic_model_9.fit_transform(data)

# %%
T_9 = topic_model_9.get_document_info(data)
docs_per_topics_9 = T_9.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics
dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_9[topico]:
    print(doc," ",data_title[doc], probs_9[doc])
len(docs_per_topics_9[topico])
# Out:
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 1.0
# 82   Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.8298092386529479
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# 95   La portada de un diario español que profundiza sobre el interés del Real Madrid por Franco Mastantuono: "Lo quieren ya" 0.8751114774479423
# 99   Vivió y corrió en Inglaterra durante la Guerra de Malvinas, compitió contra Ayrton Senna y probó un Fórmula 1: la increíble historia de Enrique Mansilla 0.6907130632257792
# 101   ¿En qué consiste el 'Meet & Greet Upgrade' con Travis Barker y cuánto cuesta? 0.45435059034392167
# 105   La dramática confesión de una figura del fútbol sobre las conmociones cerebrales que marcaron su carrera: "Dañé mi cuerpo" 0.9165907583941325
# 106   El gesto de una figura del Chelsea con un niño que generó polémica en la Premier League: ¿hubo un acto de racismo? 1.0
# 119   Dieron a conocer detalles del "pacto de silencio" entre la empleada y Christian Horner tras el escándalo en Red Bull que sacudió a la Fórmula 1 1.0
# 137   River Plate debutará en la Copa Libertadores ante Deportivo Táchira en Venezuela, en vivo: hora, TV y formaciones 1.0
# 150   Atento Boca Juniors: la Conmebol confirmó la sanción a Frank Fabra por su expulsión en la final de la Copa Libertadores 1.0
# 158   Corrida y gran definición de derecha: el gol de Thiago Messi en la Academia del Inter Miami que se hizo viral 0.6401458838906996
# 170   El incómodo encuentro de Jannik Sinner con una estrella de la música: "Es la primera de muchas citas juntos" 0.8786395885930142
# 174   La confesión de Jorge Almirón sobre Boca Juniors que causó sorpresa entre los fanáticos 1.0
# 176   Tremendo blooper: la increíble pregunta al DT de Atlético Tucumán tras empatar con Independiente - MDZ Online 1.0
# 178   En España aseguran que el Real Madrid quiere «cuanto antes» a Franco Mastantuono 0.8182584254479965
# 186   River comienza este martes a desandar su ilusión en la Copa Libertadores ante Deportivo Táchira 1.0
# 187   De no creer: tras quedar eliminados, les robaron a los jugadores en camarines y el bus los abandonó 1.0
# 189   Def. de Belgrano vs. San Telmo en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 194   Primera Nacional: Aldosivi ganó y sube de la mano de un Jorge Carranza en gran nivel 0.8826703473311118
# 204   CONMEBOL - Copa Sudamericana: Real Tomayapo vs Delfín Grupo C - Fecha 1 1.0
# 208   Los pibes de Boca que son la gran SOPRESA en la lista de la Sudamericana - TyC Sports 1.0
# 214   Aldosivi logró la victoria por 1 a 0 ante Mitre (SE) 1.0
# 220   Los recientes debuts de River en la Libertadores: de la goleada a favor a otra en contra 1.0
# 221   Sinner extiende un año colosal en Miami 0.8647774573956037
# 222   Partido de Federal A de alto voltaje: Gutiérrez y Huracán Las Heras se enfrentan en el Malvinas 1.0
# 230   Video: jugador del Chelsea fue acusado de racismo por negarle el saludo a un nene 1.0
# 239   Mundialito Infantil femenino: AEC Viedma es el flamante campeón de la tercera edición 1.0
# 244   "La Gran Revancha" ante "La Tigresa" cada vez está más cerca para Alderete 1.0
# 257   Quilmes enfrenta a Central Córdoba de Santiago del Estero por la Copa Argentina 1.0
# 261   Quiniela Nacional y Provincial: resultados del sábado 1 de abril 0.6292609585958485
# 265   Dónde ver Nacional vs. Argentinos Juniors EN VIVO hoy por la Copa Sudamericana 2024: hora y canales de TV 1.0
# 269   Una buena convocatoria entre Gutiérrez y Huracán Las Heras en el Malvinas 0.5567310951348515
# 270   Preocupación en el fútbol argentino sobre la seguidilla de lesiones ligamentarias 0.8864408016687982
# 271   Llega a su fin el básquet universitario de Estados Unidos: los cuatro que van por el título 0.4977224717491847
# 275   El tremendo palazo de Tevez a la hinchada de Independiente, que silbó al equipo: "No es fácil que te estén..." - MDZ Online 1.0
# 277   Tres mendocinos se consagraron en la Liga de Naciones de hockey sobre patines - MDZ Online 1.0
# 278   Juan Sebastián Verón volverá a ser presidente de Estudiantes de La Plata 0.8740469139415429
# 281   Tras una odisea, River llegó a Venezuela 1.0
# 282   Villarreal vs. Atlético de Madrid en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 285   Podrían llegar a Bahía Blanca dos buques para producir GNL y no se descarta un tercero - La Nueva 1.0
# 287   Defensa francés Varane dice que las conmociones cerebrales han dañado su cuerpo de forma duradera 0.9251785271195625
# 307   Unión Ezpeleta ganó en su debut en futsal en el campeonato de la AFA 0.9490816622117871
# 319   LeBron James no envejece: otra noche brillante en la NBA con 40 puntos y 9 0.5201383825069994
# 324   Franco Mastantuono fue portada en los medios españoles por el interés del Real Madrid 0.7951403382259035
# 325   Huracán inicia el camino a otra Copa, diez años después - TyC Sports 1.0
# 348   Es de Río Turbio, le mandó una carta a Marcos Rojo y cumplió su sueño 0.4587622404448818
# 356   Miguel Ángel Pierri viaja a Estados Unidos para representar a clubes europeos de primer nivel 1.0
# 358   Godoy Cruz logró un triunfazo ante Platense y sacó boleto a los cuartos de final 0.8898190975634367
# 361   Internaron a Cesar Luis Menotti y crece la preocupación 0.6933022543940742
# 362   Morena Beltrán contó cómo vivió la lesión de Lucas Blondel desde la cancha de Boca 1.0
# 364   Tevez, tras el empate de Independiente con Atlético Tucumán: "Todavía estamos vivos" y "entiendo el fastidio de la gente" 1.0
# 377   Sin Blondel, ¿qué opciones tiene Boca en el lateral derecho? - TyC Sports 1.0
# 378   El polémico video donde un periodista estrella de ESPN revela de qué club es hincha 1.0
# 379   Godoy Cruz le ganó a Platense, quedó como único líder y clasificó a los cuartos de final de la Copa de la Liga Profesional 1.0
# 387   Alemania prohíbe un número de camiseta y cambia un número por su parecido a un símbolo nazi - TyC Sports 0.4087700410025658
# 392   Belgrano y el desafío de seguir sin Ulises Sánchez 1.0
# 405   Cagliari empata el juego ante Hellas Verona 1.0
# 409   La insólita pregunta de un periodista que descolocó a Facundo Sava: "¿Te fuiste cinco minutos antes?" 1.0
# 415   "Pibe, ojalá seas el 5 por ciento de lo que fue tu abuelo", le dicen al Pékel más chico 1.0
# 423   Altamirano fue INCLUIDO por Estudiantes en la lista de la LIBERTADORES - TyC Sports 0.8593895115012062
# 426   Otro más: un nuevo jugador de Primera se rompió el ligamento cruzado anterior y es baja sensible - TyC Sports 1.0
# 431   Deportivo Táchira vs. River, por la Copa Libertadores: hora, formaciones y cómo ver en vivo 1.0
# 448   Partidos de fútbol de hoy, lunes 1 de abril: agenda, horario y cómo ver en vivo por TV 0.9388724849261402
# 449   Instituto visita a San Lorenzo en busca de la recuperación en la gira de la Liga Nacional 1.0
# 454   El Al Ittihad de Gallardo y un inoportuno traspié con Al-Ahli pensando en la Champions de Asia - TyC Sports 1.0
# 457   Racing tuvo un día libre mientras disfruta de un presente bárbaro 1.0
# 460   Accidente fatal en la ruta que Boca deberá atravesar para llegar a Potosí en Bolivia 1.0
# 474   Locura por River en Cúcuta: gran recibimiento de una multitud y caravana para escoltar Millonario 1.0
# 475   Udinese visita a Sassuolo por la fecha 30 0.9007363863744383
# 486   Pep Guardiola, el duelo con su amigo Mikel Arteta y la broma sobre cómo vulnerar a un equipo que se defiende muy atrás: ¿Matar a alguien, tal vez?" 0.969069769791637
# 491   Godoy Cruz lo ganó sobre la hora y clasificó a cuartos de final 0.8842083278620526
# 495   Bielsa se refirió a la no convocatoria de Cavani y Suárez con Uruguay: "No hay un partido que no haya visto" 1.0
# 503   ¿Qué día, a qué hora y dónde jugará Cipolletti contra Sansinena? 1.0
# 507   El jujeño Calderari recibió el "ok" de Zielinski en Lanús 0.8802976093280325
# 510   Arrancan la Copa Libertadores y la Copa Sudamericana: la agenda de partidos para los argentinos 1.0
# 511   Clasificado: Godoy Cruz le ganó en el final a Platense y jugará los cuartos de la Copa de la Liga otra vez - MDZ Online 1.0
# 513   Godoy Cruz visita a Platense para quedar como único líder 0.8496487235869561
# 526   Newell's: "Es un mala leche, un soberbio", le dijo Méndez a Espinoza 1.0
# 527   Borja, el goleador de Copa que rinde mejor con un socio de ataque 1.0
# 530   Ricardo Caruso Lombardi liquidó a uno de los delanteros de River: "No es buen definidor" 1.0
# 533   Bomba sobre Neymar: se conoció el club donde jugaría el brasileño 1.0
# 539   El enojo de Mbappé al ser reemplazado por Luis Enrique en PSG y su elocuente posteo - MDZ Online 1.0
# 547   Escándalo en Always Ready, próximo rival de Defensa y Justicia: saqueo en el vestuario y pelea entre un jugador y el presidente 1.0
# 559   Guiño al Santos: Neymar pidió que le guardaran la camiseta "11" 1.0
# 568   River, hoy EN VIVO: la previa del debut en la Libertadores y últimas noticias de este lunes 1° de abril 1.0
# 569   Polémica en la Selección alemana por supuesto simbolismo nazi en la camiseta 0.4007797223540787
# 570   Dep. Paraguayo vs. Juventud Unida en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 576   Belgrano e Internacional se encuentran en la fecha 1 del grupo C 1.0
# 577   Ganó el Atlético de Madrid de Diego Simeone: así está la Liga española 1.0
# 578   Mungo, goleadora pero con las manos vacías con Ardoi 1.0
# 581   Cañuelas derrota a Flandria2 a 1 en el estadio Carlos V 1.0
# 585   La historia de Central en sus debuts en la Copa Libertadores 1.0
# 591   Sin Blondel, la joya de 18 años que Martínez tiene en el lateral derecho y anotó en la Sudamericana 1.0
# 601   Cambaceres vs. L. N. Alem en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 627   Copa Libertadores: River pone en marcha su sueño copero en Venezuela  | El conjunto de Núñez visita a Deportivo Táchira en San Cristóbal 1.0
# 630   La rosarina Nadia Podoroska ganó su segundo título WTA en México 1.0
# 636   (VIDEO) Iñigo Martínez, jugador de Barcelona, se bajó del auto y encaró a un hincha que lo provocó 1.0
# 637   ¿Juega Messi ante Monterrey? Lo que dijo Gerardo Martino sobre el capitán 0.6784056322562181
# 639   Antes del debut copero contra Central, Peñarol emitió recomendaciones a sus hinchas por la crisis de seguridad en Rosario 1.0
# 656   Trinidense se enfrentará ante Fortaleza por la fecha 1 del grupo D 1.0
# 664   De qué manera promocionaron la llegada de Lali Esposito a la TV española - MDZ Online 1.0
# 675   Banfield lo dio vuelta en una ráfaga y ganó en Mendoza 0.9388724849261402
# 683   ◉ Atlas vs. Victoriano Arenas en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 689   Cómo ver en vivo Platense vs Godoy Cruz: fútbol libre por celular 0.8865060928059297
# 690   Rating del mes: Telefe ganó marzo y se mantuvo el encendido de los canales de aire 1.0
# 691   Debutó con Passarella, formó parte del ascenso y ahora enfrentará a River con Táchira 1.0
# 695   Así es la lista oficial de jugadores de Barcelona en la Copa Libertadores 2024 1.0
# 696   El "santo" tuvo una misión semanal clara: que el crecimiento se mantenga ante Chaco For Ever 1.0
# 706   Armando Méndez explotó contra Fernando Espinoza: "Es un mala leche, un soberbio" - TyC Sports 1.0
# 719   La probable formación de River para el estreno en la Libertadores vs. Deportivo Táchira 1.0
# 722   Qué dijo la denunciante sobre el video de los dos jugadores de Vélez saliendo de la habitación 0.919222364079851
# 725   La insólita pregunta a Sava y la respuesta del DT tras el 1-1 entre Independiente y Atlético Tucumán 1.0
# 726   Dock Sud vence a Laferrere en el estadio De Los Inmigrantes 1.0
# 733   Máxima alerta en Boca por un accidente en la ruta que debe usar para llegar a Potosí 1.0
# 739   Deportivo Táchira vs. River por la Copa Libertadores: día, horario y TV 1.0
# 742   Godoy Cruz venció a Platense con un agónico gol y se clasificó a los cuartos de final de la Copa de la Liga 0.8489202061901733
# 748   Los cuatro posibles rivales de Villa Mitre en playoffs de Liga Argentina 0.9494970729175956
# 749   Los 37 años de Dalma Maradona: la historia detrás del auto que Diego le regaló de chica y que ella devolvió 1.0
# 750   Belgrano enfrenta al Inter en su debut en la Copa Sudamericana: hora, TV y posible formación 1.0
# 754   ◉ Lecce vs. Roma en vivo: seguí el partido minuto a minuto - TyC Sports 1.0
# 756   Walter Perazzo: "Hicimos méritos para el empate" 1.0
# 762   Atlético sigue sin ganar porque Sava erró los cambios y los jugadores no liquidaron el duelo 0.9950355844418327
# 765   Valentín Jouglard: "Liniers, sin dudas, está para pelear el campeonato" 1.0
# 784   La lista de Belgrano para su debut internacional, con un par de regresos importantes 1.0
# 789   Atacó a golpes a su padre porque le pidió plata y no tenía 0.6609970650652593
# 792   Falleció Alejandro "Polaco" Semenewicz, un multicampeón con Independiente - TyC Sports 1.0
# 808   El posteo del Colo Barco tras su debut en la Premier League - TyC Sports 1.0
# 813   Independiente no pudo con Atlético Tucumán y se complicó | El club de Avellaneda empató en su estadio y está sexto en el grupo 1.0
# 816   Video: lo echaron y quiso pegarle al arquero suplente de Godoy Cruz 1.0
# 831   Godoy Cruz puso el 2 a 1 contra Platense en tiempo de descuento 1.0
# 836   Fixture Copa Libertadores 2024: calendario de partidos y grupos - TyC Sports 0.899812196200164
# 838   Polémica entre el Gallego Insua y la dirigencia de San Lorenzo tras perder ante Boca y a horas del debut en la Libertadores - MDZ Online 1.0
# 841   Fútbol libre por celular: cómo ver en vivo Central Córdoba vs. Quilmes 1.0
# 845   Mbappé habló de Lionel Messi y no "arrugó" ni un poco: "Es..." | Crónica | Firme junto al pueblo 0.9911818947800047
# 849   Independiente igualó con Atlético Tucumán y complicó su pase a la fase final de la Copa de la Liga Profesional 1.0
# 852   Belgrano buscará un reemplazo para Ulises Sánchez, cuándo lo hará 0.9463358100336717
# 855   Los "nuestros" juegan el domingo y la cancha de La Armonía debuta en el Federal A 1.0
# 857   Los 10 datos más curiosos en la historia de la NBA 0.5385628584473661
# 874   La vez en la que un MVP de la NBA visitó Tucumán y jugó en Villa Luján 1.0
# 878   Dolor en Independiente: murió Alejandro Semenewicz, leyenda del club - MDZ Online 1.0
# 894   La sorpresiva revelación de Diego Latorre sobre el equipo del que es hincha su esposa: "Yanina es de…" - MDZ Online 1.0
# 903   Argentina - Copa de la Liga Profesional: Banfield vs Independiente Fecha 13 1.0
# 904   Un jugador de Newell's estalló contra Fernando Espinoza: "Es un payaso, mala leche y soberbio" 1.0
# 906   Gutiérrez-Huracán Las Heras, promesa de partidazo en el Malvinas - MDZ Online 0.9969468511746145
# 908   Jannik Sinner es el nuevo número 2 del mundo: cómo quedó el ranking ATP - TyC Sports 0.8821244469760658
# 914   Flandria vs. Cañuelas en vivo: cómo verlo, horario y TV - TyC Sports 1.0
# 923   Nacional (P) vs. Argentinos Juniors por la Copa Sudamericana: día, horario y TV 1.0
# 925   Bomba: aseguran que Neymar Junior jugará en Santos a partir de 2025 1.0
# 930   Serie A de Italia: Inter, esta vez sin goles de Lautaro Martínez, ganó y ya calcula cuándo se llevará el scudetto 1.0
# 947   La importante decisión que tomó Estudiantes con Javier Altamirano tras recibir el alta médica 0.852150496917237
# 952   Estudiantes viaja a Chile para enfrentar a Huachipato - TyC Sports 0.9160432308797412
# 958   ¿Lo mufó o fue sincero?: la particular frase del DT de Bayern Múnich para el Leverkusen, líder de la Bundesliga - MDZ Online 1.0
# 963   Gabigol en otra polémica: su continuidad en Flamengo 1.0
# 970   El sorpresivo equipo de Boca para el debut en la Copa Sudamericana 0.8774763782478562
# 975   Jujuy Básquet consiguió un ajustado triunfo ante Belgrano de Tucumán 1.0
# 976   Las palabras de Juan Carlos Olave luego de conseguir su tercer triunfo seguido con Racing 1.0
# 979   Atlético Tucumán: estuvo a punto... pero sigue sin ganar en la Copa de la Liga 1.0
# 981   Boca, habilitado a incorporar por la lesión de Lucas Blondel 1.0
# 988   El gesto de Estudiantes con Altamirano y la preocupación por Carrillo antes de viajar a Chile 1.0
# 990   La llave de la Copa Argentina: tres partidos en medio del comienzo de Libertadores y Sudamericana 1.0
# 162

# %%
topico = 10
for doc in docs_per_topics_9[topico]:
    print(doc," ",data_title[doc], probs_9[doc])
len(docs_per_topics_9[topico])
# Out:
# 31   Murió la escritora Maryse Condé, activista contra la esclavitud y el racismo que ganó el "Nobel alternativo" 0.44481632422857215
# 54   Cinco libros esenciales para conocer la obra de Maryse Condé 0.7236069956502477
# 110   El desgarrador mensaje de la madre de la esposa del golfista Emilio Domínguez que murió de dengue 1.0
# 247   Quién era María Victoria De La Mota Claverie, la esposa del golfista Emilio Domínguez que murió por dengue 1.0
# 267   Jaime López Rivarola sobre el fallecimiento de la esposa de Emilio Domínguez: "Queremos que sepa que todos sus amigos están pensando en él" 0.5327425952750301
# 296   Quién era María Victoria De La Mota Claverie, la mujer del golfista argentino que murió por dengue 1.0
# 297   Quién era María Victoria De La Mota Claverie, la joven esposa del "Puma" Domínguez que murió por dengue 0.8884201496296111
# 301   Murió de dengue la mujer de Emilio "Puma" Domínguez, reconocido jugador de golf argentino 0.9863040097255273
# 363   Murió de dengue la esposa del golfista argentino Emilio Domínguez 1.0
# 401   Cumplió 117 años y contó los secretos para vivir tanto tiempo: el alimento que come todos los días 1.0
# 443   Dolor por la esposa del Puma Domínguez, quien murió de dengue, mientras él jugaba en México 1.0
# 462   Murió de dengue la esposa del golfista argentino Emilio Domínguez 0.9872921052399104
# 709   Dengue: murió un adolescente de 13 años en Catamarca 0.24575804370689108
# 721   Conmoción en el ambiente del básquet: murió el padre del Penka Aguirre 0.30919434431004883
# 738   Conmoción en el golf: la esposa del jugador argentino Emilio Domínguez murió tras contagiarse dengue 1.0
# 768   Murió de dengue la esposa del golfista Emilio Dominguez 1.0
# 835   DRAMA en Independiente: MURIÓ Alejandro Semenewicz de un paro cardíaco 0.30367923704344657
# 881   El dengue sigue descontrolado: murió la esposa del golfista argentino Emilio Domínguez 1.0
# 939   Quién era María Victoria De La Mota Claverie, la esposa de un conocido golfista que murió por dengue - MDZ Online 1.0
# 965   Quién era Victoria, la mujer del golfista Emilio Domínguez que falleció por dengue 0.8848919100197158
# 20

# %%
len(docs_per_topics_9[-1])
# Out:
# 215

# %%
# Obtener las palabras clave de un tema específico
topic_keywords = topic_model_9.get_topic(10)  # Cambiar 0 por el ID del tema deseado
print(topic_keywords)
# Out:
# [('karina milei', 0.5174929), ('monumento', 0.45645806), ('jorge macri', 0.42519456), ('secretaria', 0.41240472), ('argentinos', 0.40678596), ('milei', 0.4064965), ('presidente', 0.40557232), ('reino', 0.4045558), ('carlos sadir', 0.40445343), ('senado', 0.402051)]

# %% [markdown]
# - 9. Con 1000 registros:
#     - Es muy importante validar el tipo de sentence transformer, en este caso debe ser multilingual

# %% [markdown]
# ## Test 10- Documentos preprocesados + cfg BERTopic

# %%
# Stopwords
SPANISH_STOPWORDS = list(pd.read_csv(PATH+'spanish_stop_words.csv' )['stopwords'].values)
SPANISH_STOPWORDS_SIN_ACENTOS = [unicodedata.normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in SPANISH_STOPWORDS]

# %%
# Limpiar texto
cleaner = Cleaning_text()

docs_clean = []
for doc in data:
    clean_txt = cleaner.unicode(doc)
    clean_txt = cleaner.urls(clean_txt)
    clean_txt = cleaner.simbols(clean_txt)
    clean_txt = cleaner.accents_emojis(clean_txt)
    clean_txt = cleaner.escape_sequence(clean_txt)
    docs_clean.append(cleaner.str_lower(clean_txt))

# Eliminamos stopwords del corpus
preprocessed_data = []
registro = ""
for txt in docs_clean:
    for word in txt.split():
        if word.isalpha() and not word in SPANISH_STOPWORDS_SIN_ACENTOS:
            registro += word + " "
        elif word.isnumeric():
            registro += word + " "
    preprocessed_data.append(registro+' ')
    registro = ""

# %%
tfidf_vectorizer_10 = TfidfVectorizer(
    # tokenizer=tokenizer,
    max_df=0.9,
    min_df=0.1,
    ngram_range=(1, 2),
    #stop_words=SPANISH_STOPWORDS,
    lowercase=True,
    #vocabulary=vocab_entities,
    # max_features=100_000
)
tfidf_vectorizer_10.fit(preprocessed_data)

# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')
# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
# Step 4 - Tokenize topics
vectorizer_model = tfidf_vectorizer_10
# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer()
# Step 6 - (Optional) Fine-tune topic representations with a `bertopic.representation` model
representation_model = KeyBERTInspired()

# All steps together
topic_model_10 = BERTopic(
  embedding_model=embedding_model,            # Step 1 - Extract embeddings
  umap_model=umap_model,                      # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,                # Step 3 - Cluster reduced embeddings
  vectorizer_model=tfidf_vectorizer_10,          # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                  # Step 5 - Extract topic words
  representation_model=representation_model,  # Step 6 - (Optional) Fine-tune topic represenations
  language='spanish',
  #calculate_probabilities=True
)

topics_10, probs_10 = topic_model_10.fit_transform(preprocessed_data)

# %%
T_10 = topic_model_10.get_document_info(data)
docs_per_topics_10 = T_10.groupby(["Topic"]).apply(lambda x: x.index).to_dict()
docs_per_topics_10
# Out:
# {-1: Index([  2,  15,  19,  30,  32,  40,  46,  53,  59,  62,
#         ...
#         945, 946, 948, 961, 962, 964, 972, 982, 985, 993],
#        dtype='int64', length=155),
#  0: Index([  3,   4,   5,   7,  11,  12,  13,  14,  16,  17,
#         ...
#         979, 981, 983, 984, 986, 987, 988, 989, 990, 999],
#        dtype='int64', length=500),
#  1: Index([ 10,  24,  25,  29,  35,  45,  56,  65,  73,  80,  84, 100, 108, 111,
#         124, 129, 131, 132, 157, 160, 161, 169, 202, 205, 206, 207, 237, 252,
#         255, 293, 300, 376, 398, 402, 407, 410, 421, 428, 442, 456, 473, 493,
#         514, 520, 531, 541, 556, 557, 571, 580, 605, 642, 647, 658, 665, 673,
#         674, 703, 718, 720, 723, 737, 740, 767, 790, 803, 804, 810, 825, 834,
#         842, 853, 858, 870, 873, 919, 926, 942, 992, 995],
#        dtype='int64'),
#  2: Index([  1,   6,   9,  34,  51,  61, 112, 165, 168, 172, 180, 192, 193, 213,
#         233, 240, 243, 276, 280, 316, 326, 335, 338, 342, 346, 353, 380, 397,
#         436, 452, 483, 484, 499, 518, 540, 544, 554, 562, 566, 586, 587, 594,
#         604, 616, 619, 622, 628, 638, 644, 659, 663, 670, 671, 678, 679, 699,
#         708, 743, 758, 764, 773, 793, 796, 798, 818, 886, 889, 909, 910, 912,
#         932, 969, 974, 997, 998],
#        dtype='int64'),
#  3: Index([ 22,  28,  55,  68,  86, 136, 162, 177, 223, 251, 254, 261, 354, 359,
#         406, 411, 417, 505, 517, 522, 574, 579, 590, 657, 690, 735, 759, 774,
#         777, 812, 907, 944, 966, 991, 994],
#        dtype='int64'),
#  4: Index([  0,  26,  88, 142, 236, 273, 283, 350, 395, 418, 435, 458, 487, 525,
#         546, 548, 588, 589, 598, 610, 715, 757, 763, 847, 850, 863, 867, 934,
#         950, 996],
#        dtype='int64'),
#  5: Index([102, 209, 248, 294, 305, 314, 341, 344, 373, 391, 427, 429, 445, 467,
#         516, 602, 620, 651, 655, 667, 709, 772, 811, 865, 868, 893],
#        dtype='int64'),
#  6: Index([  8,  52,  67,  72, 123, 151, 166, 182, 201, 226, 260, 288, 292, 340,
#         464, 532, 603, 654, 885, 911, 918, 928, 933, 957, 978],
#        dtype='int64'),
#  7: Index([ 27,  38, 103, 127, 198, 228, 229, 258, 311, 367, 375, 490, 500, 536,
#         542, 676, 701, 711, 814, 860, 861, 898, 938, 956],
#        dtype='int64'),
#  8: Index([191, 246, 279, 303, 312, 345, 372, 434, 521, 529, 649, 692, 713, 727,
#         728, 761, 809, 822, 854, 876, 896, 931, 980],
#        dtype='int64'),
#  9: Index([104, 210, 259, 388, 439, 466, 478, 572, 596, 646, 681, 686, 788, 806,
#         875],
#        dtype='int64'),
#  10: Index([247, 296, 297, 301, 363, 443, 462, 738, 768, 881, 939, 965], dtype='int64')}

# %%
topico = 0
for doc in docs_per_topics_9[topico]:
    print(doc," ",data_title[doc], probs_9[doc])
len(docs_per_topics_9[topico])
# Out:
# 23   Arranca la Copa Sudamericana: la agenda con el debut de Belgrano de Córdoba, Argentinos Juniors y Defensa y Justicia 1.0
# 39   La sugerente frase de una ex figura de Boca Juniors antes de enfrentar al Inter Miami: "Messi es un atractivo diferente para los árbitros" 1.0
# 82   Arden las tablas de la Copa de la Liga: Godoy Cruz es el primer clasificado, Boca afuera, River adentro y los posibles cruces de cuartos 0.778884716776962
# 93   Comienza la ilusión continental: premios, formatos, partidos y todo lo que hay que saber de las Copas Libertadores y Sudamericana 1.0
# 166

# %%
topico = 10
for doc in docs_per_topics_9[topico]:
    print(doc," ",data_title[doc], probs_9[doc])
len(docs_per_topics_9[topico])
# Out:
# 19   En el homenaje a los caídos en Malvinas, Milei convocó a una nueva era de reconciliación con las Fuerzas Armadas 0.5402068514750463
# 27   Milei y Villarruel encabezarán el acto central por el 42º aniversario de la Guerra de Malvinas 1.0
# 38   La emoción de la vicepresidenta al recordar a su padre: quién fue el héroe de Malvinas Eduardo Marcelo Villarruel 0.849109169792249
# 103   Milei y Villarruel encabezarán el acto central a 42 años de Malvinas: habrá cadena nacional 1.0
# 132   Alberto Fernández y Cristina Kirchner se expresaron por el Día del Veterano y los Caídos en Malvinas 0.6844668110411296
# 171   Milei espera que se mantenga el descenso de la inflación en los próximos meses 0.5427556446918097
# 228   Milei rendirá homenaje a los caídos en Malvinas, a 42 años del inicio de la Guerra 1.0
# 245   Vendimia para Todxs cerró su edición 2024 con una fiesta que reunió a 1.500 personas 0.5543662670901087
# 258   El Gobernador homenajeo a los Veteranos de Malvinas 1.0
# 311   Se cumplen 19 años del fallecimiento del Papa Juan Pablo II 0.8794880821983363
# 339   Agendas separadas: Milei, Villarruel y los diferentes actos por Malvinas que encabezarán - Big Bang! News 0.8994743302496556
# 352   A 42 años del inicio de la Guerra de Malvinas, Milei rinde homenaje a los caídos 1.0
# 375   Milei rendirá homenaje a los caídos en Malvinas 1.0
# 477   La Municipalidad desplegó un operativo integral por las pascuas en el cementerio "La Piedad " 0.5382888316078204
# 500   Milei, a excombatientes de Malvinas: "Tendrán el respeto que les ha sido negado" 0.9275762172746314
# 536   El Presidente encabezará el acto por Malvinas 1.0
# 676   La emoción de Victoria Villarruel en el acto en homenaje a los caídos de Malvinas y el abrazo con Milei 1.0
# 701   Así celebraron los famosos el Domingo de Pascuas 0.4848014699274277
# 814   Acto por Malvinas: Javier Milei rendirá homenaje a los caídos y compartiría el evento con Villarruel 1.0
# 861   Milei, la Vice y Malvinas: un cruce con agendas separadas | El otro foco de tensión en el Gobierno 1.0
# 898   Dinelli, el sacerdote por el Tercer Mundo secuestrado y exiliado que nunca declaró 0.4613565059971143
# 956   Milei en el homenaje a los caídos y veteranos de Malvinas: "No existe soberanía sin prosperidad económica" 0.7667923619529822
# 22

# %%
len(docs_per_topics_9[-1])
# Out:
# 215

# %%
# Obtener las palabras clave de un tema específico
topic_keywords = topic_model_9.get_topic(10)  # Cambiar 0 por el ID del tema deseado
print(topic_keywords)
# Out:
# [('karina milei', 0.5174929), ('monumento', 0.45645806), ('jorge macri', 0.42519456), ('secretaria', 0.41240472), ('argentinos', 0.40678596), ('milei', 0.4064965), ('presidente', 0.40557232), ('reino', 0.4045558), ('carlos sadir', 0.40445343), ('senado', 0.402051)]

# %% [markdown]
# - 9. Con 1000 registros:
#     - Es muy importante validar el tipo de sentence transformer, en este caso debe ser multilingual

# %% [markdown]
# # Evaluacion final

# %%
topico = 15
for doc in docs_per_topics_5[topico][:20]:
    print(doc," ",data_title[doc], probs_5[doc])
len(docs_per_topics_5[topico])
# Out:
# 264   La empresa propietaria de la Fórmula 1 compra Moto GP 1.0
# 333   Los dueños de la Fórmula 1 pagaron miles de millones para subirse a MotoGP 1.0
# 515   Legislatura de la provincia | Últimas noticias El Tribuno 1.0
# 648   Día Mundial del autismo | Últimas noticias El Tribuno 1.0
# 688   Yerba Buena: llegan los radares a la avenida Perón, ¿a qué velocidad podés circular? 1.0
# 724   DALE AL MEDIO                  - TyC Sports 1.0
# 747   entrevista exclusiva El Tribuno | Últimas noticias El Tribuno 1.0
# 843   La Fórmula 1 compra MotoGP: los detalles del acuerdo multimillonario - TyC Sports 1.0
# 884   Turismo en Semana Santa | Últimas noticias El Tribuno 1.0
# 920   Liga Argentina de Básquetbol | Últimas noticias El Tribuno 1.0
# 985   Día de los Veteranos y Caídos en Malvinas | Últimas noticias El Tribuno 1.0
# 11

# %%
topico = 15
for doc in docs_per_topics_9[topico][:20]:
    print(doc," ",data_title[doc], probs_9[doc])
len(docs_per_topics_9[topico])
# Out:
# 136   Marzo fue el décimo mes consecutivo en romper récords de altas temperaturas globales 1.0
# 162   Último día del fin de semana largo: cuál es el pronóstico del tiempo para este martes 1.0
# 223   Emiten alerta naranja por viento y lluvia para este martes 1.0
# 254   Pronóstico: para mañana se espera un aumento de la temperatura y alerta por Zonda y sectores del Gan Mendoza 1.0
# 354   El tiempo en Santiago del Estero: máxima de 26ºC y probabilidad de precipitaciones para el inicio de abril 1.0
# 359   Inicio de semana fresco y con un cielo parcialmente nublado - MDZ Online 1.0
# 420   "Villa Mitre será tan duro como lo fue River el viernes", dijo el DT de Huracán 0.47656154426899694
# 505   El cielo estará nublado y se esperan lluvias durante toda la jornada en Tucumán 1.0
# 517   Lunes caluroso en Misiones, con pronostico de lluvias y chaparrones aislados 1.0
# 907   Clima en Córdoba: fuerte descenso de la temperatura para el lunes, ¿llega la lluvia? 1.0
# 966   Alerta por viento y lluvia, este martes y miércoles, en Neuquén y Río Negro: habrá ráfagas de 120 km/h 1.0
# 991   🟠 Lanzaron una alerta naranja por fuertes vientos: qué provincias serán afectadas 1.0
# 12

# %%
titulos = [
    "Javier Milei",
    "Guillermo Francos",
    "Milei",
    "Javier",
    "Diana Mondino"
]

# %%
# Obtener las últimas palabras de las entidades con más de una palabra
ultimas_palabras = [titulo.split()[-1] for titulo in titulos if len(titulo.split()) > 1]
ultimas_palabras
# Out:
# ['Milei', 'Francos', 'Mondino']

# %%
# Filtrar si las últimas palabras coinciden con alguna unica palabra
filtro_ulp = [titulo for titulo in titulos if not (len(titulo.split()) == 1 and titulo in ultimas_palabras)]
filtro_ulp
# Out:
# ['Javier Milei', 'Guillermo Francos', 'Javier', 'Diana Mondino']

# %%
# Obtener las palabras únicas
unicas_palabras = [ palabra for palabra in resultado if len(palabra.split()) == 1]
unicas_palabras
# Out:
# ['Javier']

# %%
# Filtrar si las palabras únicas coinciden con las una entidad con más de una palabra
filtro_unp = [ titulo for titulo in filtro_ulp if not titulo in unicas_palabras ]
filtro_unp
# Out:
# ['Javier Milei', 'Guillermo Francos', 'Diana Mondino']
